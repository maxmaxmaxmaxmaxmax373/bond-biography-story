# %% [markdown]
# (bond-20120-four-and-one-half-percent-loan-of-1891)=
# # Bond Biography: Four and One-Half Percent Loan of 1891
#
# *Bond ID:* **20120** · *Bayley reference:* ch. 4 (*Funded Loans of 1881, 1891, and 1907*) · *Database series:* `BondList[20120]`, `BondPrice_T[(20120, 'Average')]`, `BondQuant_T[(20120, ...)]`
#
# ---
#
# > *"The reduction in the rate of interest on the public debt… effected an annual saving to the Treasury of many millions of dollars, and demonstrated anew the soundness of the national credit."*
# > — John Sherman, *Annual Report*, 1881 — quoted in Bayley, ch. 4.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
import datetime
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'figure.figsize': (14, 6),
    'font.size': 12,
    'axes.titlesize': 15,
    'axes.labelsize': 12,
    'figure.dpi': 110
})

store = pd.HDFStore('../data/BondDF.h5', mode='r')
BondList  = store['BondList']
BondQuant = store['BondQuant']
BondPrice = store['BondPrice']
store.close()

BondQuant_T = BondQuant.transpose()
BondPrice_T = BondPrice.transpose()

bond_id = 20120
print(f"Loaded data for: Four and One-Half Percent Loan of 1891 — Bond ID {bond_id}")
print(f"Database contains {len(BondList):,} bond issues spanning {BondList['First Issue Date'].min().year}–{BondList['First Issue Date'].max().year}")
# Out:
# Loaded data for: Four and One-Half Percent Loan of 1891 — Bond ID 20120
# Database contains 2,857 bond issues spanning 1777–2015

# %% [markdown]
# ## Overview
#
# Rafael A. Bayley, writing in 1881 in his *National Loans of the United States*, framed this loan in the following terms:
#
# > The act of July 14, 1870 (16 Statutes, 272), authorized the issue of bonds, in three classes — fifteen years at four and a half per cent., ten years at five per cent., and thirty years at four per cent.
#
# — Bayley, ch. 4, on the Funded Loans of 1881, 1891, and 1907.
#
# That contemporary framing is the place to begin. The modern paragraphs that follow extend it with the secondary-market data the Hall–Payne–Sargent Bond Database makes available, and with the broader 21st-century historiographical literature on the loan.
#
# The **Four and One-Half Percent Loan of 1891** is the clearest embodiment of what the Gilded Age Treasury called **"refunding the public debt"** — the systematic replacement of high-coupon Civil War–era obligations with new, lower-coupon instruments. Authorized under the pivotal **Funding Act of July 14, 1870** but not first issued until 1877 (after the Panic of 1873 delayed earlier placement attempts), the 4.5% Loan was a direct response to a simple but powerful fact: by the late 1870s, the general market rate on long-dated, credit-worthy sovereign debt had fallen well below the 6% carried by Civil War Five-Twenties and Consols.
#
# With a **4.5% coupon paid quarterly** (a departure from the semi-annual pattern of earlier Treasury bonds, and closer to the typical European government-bond standard), the bond was designed to appeal simultaneously to:
# - **Domestic trustees and savings institutions**, which valued the steadier cash-flow profile of quarterly coupons
# - **European investors** in London, Paris, and Amsterdam, who were now more open to American sovereign debt after the resumption of specie payments (1879) had restored the gold standard
# - **National banks**, which continued to hold federal bonds as reserves against their banknote issues
#
# The Hall-Payne-Sargent database records the 4.5% Loan in **181 monthly price observations** (September 1876 – September 1891). Mean price: **\$108.89**. Range: **\$99.50** (September 1891, at the redemption point when refunding was imminent) to **\$116.00** (April 1882, the peak of the bond's premium). Peak outstanding: **\$258.0 million**.

# %% [markdown]
# ## Bayley's Account in Detail (1881)
#
# Bayley's 1881 *National Loans of the United States* devotes substantive attention to this bond. Four passages from his account are reproduced below, with modern commentary woven in. They give the reader the primary-source spine of this biography — the statute text, the placement mechanics, and the post-issuance disposition as recorded by the U.S. Treasury Department officer who compiled the original.
#
# ### The authorizing statute
#
# Bayley begins his account, as he does for every loan in his book, with the statutory text. For this bond he writes:
#
# > Be it enacted by the Senate and House of Representatives of the United States of America in Congress assembled, That the Secretary of the Treasury is hereby authorized to issue … a sum or sums not exceeding in the aggregate three hundred million dollars of like bonds, the same in all respects, but payable at the pleasure of the United States after fifteen years from the date of their issue, and bearing interest at the rate of four and a half per cent. per annum.
#
# — *Bayley, ch. 4 (Funded Loans of 1881, 1891, and 1907), p. 461 — quoting the 4.5% provision of the Funding Act of July 14, 1870 (16 Statutes, 272).*
#
# That paragraph is the legal foundation of the bond. Every subsequent operational and financial detail in this biography follows from the statutory powers it conferred on the Treasury.
#
# ### How it was actually placed
#
# Bayley then describes how the Treasury translated statutory authority into actual placement — the subscribers, the marketing, the prices realized, the political context that shaped market reception:
#
# > The essential conditions of the new loan appear to me to be these: 1. That the principal and interest shall be made payable in coin. 2. That the bonds known as the five-twenty bonds shall be received in exchange for the new bonds. 3. That the principal be payable in this country, and the interest payable either in the United States or in Europe, as the subscribers to the loan may desire. 4. That the rate of interest shall not exceed 4½ per cent. per annum. 5. That the subscribers in Europe shall receive their interest at London, Paris, Berlin, or Frankfort, as they may elect.
#
# — *Bayley, ch. 4 — Treasury Secretary George Boutwell, *Annual Report*, December 6, 1869, articulating the design principles for the refunding bonds.*
#
# This operational detail is the kind of material that distinguishes Bayley's primary-source account from purely statistical sources. The price and quantity series in the Hall–Payne–Sargent database tell us *what* happened in the secondary market; Bayley tells us *how* it happened in the primary placement.
#
# ### Outstanding amounts and disposition
#
# Bayley closes most of his loan accounts with concrete tabulated figures — total amount issued, distribution among holders, ultimate retirement schedule:
#
# > Bonds have been sold for resumption purposes since March 1, 1877, amounting to \$65,000,000 of the 4½ per cent. loan of 1891, and \$25,000,000 of the 4 per cent. loan of 1907. … The whole amount of bonds issued under the several refunding acts are as follows: Five per cent. loan of 1881, \$517,494,150; Four and one-half per cent. loan of 1891, \$250,000,000; Four per cent. loan of 1907, \$739,480,800.
#
# — *Bayley, ch. 4 — the final cumulative issuance under the Funding Act of 1870, totaling roughly \$1.5 billion across the three classes.*
#
# These figures are the data that the modern Hall-Payne-Sargent database extends and corroborates. Where Bayley's tabulated total matches the database's monthly outstanding peak (within rounding), we have strong confidence in the bond's accounting; where they differ, the discrepancy itself carries information about how 19th-century federal debt was tracked.
#
# ### Political and fiscal context
#
# Bayley also frequently records the political backdrop — the wartime urgency, the legislative debate, the economic conditions — that shaped the placement:
#
# > Interest-bearing debt, March 1, 1871: \$1,977,581,700 00. Interest-bearing debt, July 1, 1880: \$1,723,993,100 00. Reduction in interest-bearing debt: \$253,588,600 00. Annual interest charge, March 1, 1871: \$114,858,869 00. Annual interest charge, July 1, 1880: \$79,633,981 00. Reduction in annual interest charge: \$35,224,888 00.
#
# — *Bayley, ch. 4 — the refunding scoreboard: \$253M debt reduction and \$35M annual interest savings achieved in less than a decade of refunding operations.*
#
# Read the modern paragraphs that follow with these four Bayley passages in mind. The 21st-century historiography extends Bayley's account; it does not replace it.

# %% [markdown]
# ## The Funding Act of 1870 — A New Chapter
#
# The **Act of July 14, 1870** is one of the most consequential fiscal statutes of the post-Civil War era. Its stated goal was to **reduce the annual interest burden of the federal debt** by authorizing the Treasury to issue new bonds at lower coupons to refinance outstanding 6% Civil War obligations. The Act created three distinct refunding instruments:
#
# | Bond ID | Name | Coupon | Term | Role |
# |---------|------|--------|------|------|
# | 20119 | Five Percent Loan of 1881 | 5.0% | 10 years | Intermediate refunding |
# | **20120** | **4.5% Loan of 1891** (this bond) | **4.5%** | **15 years** | **Medium-long refunding** |
# | 20121 | Four Percent Loan of 1907 | 4.0% | 30 years | Long-term refunding |
#
# The three instruments formed a **refunding ladder**. Over the 1870s, the Treasury used them opportunistically — issuing whichever was best-suited to prevailing market conditions. The 4.5% Loan served the middle of this ladder, intended for investors who found the 5% too short and the 4% too low-yielding.
#
# ### Delayed Launch
#
# The 4.5% Loan was authorized in 1870 but not first issued until 1877 because of three factors:
# 1. **Lingering gold-vs-greenback uncertainty** discouraged European buyers in the early 1870s.
# 2. **The Panic of 1873** disrupted bond markets for several years.
# 3. **Republican political consensus** on refunding had to be rebuilt after the 1874 midterms, in which Democrats took the House.
#
# By 1877 — under Secretary **John Sherman** (yes, the same Sherman whose brother had taken Atlanta, and who had been Jay Cooke's key Congressional ally in the 1860s) — all three conditions had improved. Sherman launched the 4.5% Loan in June 1877 and oversaw its successful placement over the next several years.

# %% [markdown]
# ## Bond Features
#
# | Feature | Detail |
# |---------|--------|
# | **Name** | Four and One-Half Percent Loan of 1891 |
# | **Authorizing Act** | July 14, 1870 |
# | **First Issue Date** | June 30, 1877 |
# | **Redeemable After** | September 1, 1891 |
# | **Term** | 15 years |
# | **Coupon Rate** | 4.5% per annum |
# | **Coupon Frequency** | **Quarterly**, coin-payable |
# | **Callable** | No |
# | **Price Sold** | Par |
# | **Peak Outstanding** | \$258.0 million |

# %%
row = BondList.loc[20120]
display_cols = [
    "Treasury's Name Of Issue", 'Authorizing Act', 'Term Of Loan',
    'First Issue Date', 'Redeemable After Date', 'Payable Date',
    'Coupon Rate', 'Coupons Per Year', 'Callable', 'Coin',
    'Price Sold', 'Category L3'
]
print('Bond Features from Database:')
print('=' * 60)
for col in display_cols:
    if col in row.index:
        val = row[col]
        if pd.notna(val) and str(val).strip() != 'nan':
            print(f'  {col:<28} {val}')
# Out:
# Bond Features from Database:
# ...
#   Treasury's Name Of Issue     Four and One-Half Percent Loan of 1891
#   Authorizing Act              July 14, 1870
#   Term Of Loan                  15 years
#   First Issue Date             1877-06-30 00:00:00
#   Redeemable After Date        1891-09-01 00:00:00
#   Coupon Rate                  4.5
#   Coupons Per Year             4.0
#   Callable                     0.0
#   Coin                         1.0
#   Price Sold                   1.0
#   Category L3                  Long Term Bond

# %% [markdown]
# ## Historical Context
#
# | Date | Event | Category |
# |------|-------|----------|
# | 1870-07-14 | Funding Act | Legislation |
# | 1873-09-18 | Panic of 1873 | Crisis |
# | 1875-01-14 | Specie Payment Resumption Act | Legislation |
# | 1876-09-30 | First database price observation | Bond |
# | 1877-03-08 | John Sherman becomes Treasury Secretary | Politics |
# | 1877-06-30 | First issue | Bond |
# | 1879-01-01 | Resumption of specie payments | Monetary |
# | 1881-07-02 | President Garfield shot | Politics |
# | 1881-09-19 | Garfield dies; Arthur becomes President | Politics |
# | 1882 | Peak price (\$116, April 1882) | Bond |
# | 1890 | Sherman Silver Purchase Act; Sherman Anti-Trust Act | Legislation |
# | 1891-09-01 | Redemption date reached | Bond |

# %%
fig, ax = plt.subplots(figsize=(16, 4.5))
from datetime import datetime as dt

lifecycle = [
    ('Funding Act', '1870-07-14', '#2ecc71'),
    ('Panic of 1873', '1873-09-18', '#9b59b6'),
    ('Resumption Act', '1875-01-14', '#2ecc71'),
    ('First Issue', '1877-06-30', '#1f77b4'),
    ('Specie Resumption', '1879-01-01', '#2ecc71'),
    ('Garfield Assassinated', '1881-09-19', '#95a5a6'),
    ('Peak Price', '1882-04-30', '#27ae60'),
    ('Sherman Act', '1890-07-02', '#2ecc71'),
    ('Redemption Date', '1891-09-01', '#e67e22'),
]

ax.axvspan(mdates.date2num(dt.strptime('1873-09-18', '%Y-%m-%d')), mdates.date2num(dt.strptime('1879-03-01', '%Y-%m-%d')), alpha=0.15, color='#9b59b6', label='Long Depression')

for i, (label, date_str, color) in enumerate(lifecycle):
    d = dt.strptime(date_str, '%Y-%m-%d')
    y_pos = 0.3 if i % 2 == 0 else -0.3
    ax.plot(mdates.date2num(d), 0, 'D', color=color, markersize=9, zorder=5)
    ax.annotate(f'{label}\n{date_str}', (mdates.date2num(d), y_pos),
                ha='center', va='bottom' if y_pos > 0 else 'top',
                fontsize=7.5, fontweight='bold', color=color,
                arrowprops=dict(arrowstyle='->', color=color, lw=0.8))

ax.set_yticks([])
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.set_title('Four and One-Half Percent Loan of 1891 — Lifecycle Timeline', fontsize=14, fontweight='bold')
ax.set_ylim(-1.2, 1.2)
ax.legend(loc='upper right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quantity Outstanding
#
# The quantity profile of the 4.5% Loan has a distinctive **triangular shape**:
# 1. **Rapid issuance 1877–1881** took outstanding balance from zero to its \$258 million peak.
# 2. **Plateau through the 1880s** as the bond served as a stable benchmark in the refunded debt portfolio.
# 3. **Sharp decline after 1891** as the redemption date passed and the Treasury called in the bonds (ultimately replacing them with the 2% Funded Loan of 1891 — Bond ID 20127 — which continued the rate-compression cycle).
#
# By late 1891, outstanding had collapsed from \$258M to \$28M, and the bond was essentially retired shortly thereafter.

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6', label='Panic of 1873 / Long Depression')
for stype, color, ls in [('Public Holdings', '#1f77b4', '-'),
                          ('Total Outstanding', '#ff7f0e', '--')]:
    try:
        s = BondQuant_T.loc[(20120, stype)]
        s = s[s.notna()].sort_index()
        if len(s) > 0:
            ax.plot(s.index, s.values / 1e6, linewidth=2, linestyle=ls, color=color,
                    label=stype, marker='.', markersize=3)
    except KeyError:
        pass

ax.set_title('Four and One-Half Percent Loan of 1891 — Outstanding Quantity', fontsize=14, fontweight='bold')
ax.set_xlabel('Date'); ax.set_ylabel('Amount ($ millions)')
ax.legend(fontsize=10); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        s = BondQuant_T.loc[(20120, stype)]
        s = pd.to_numeric(s, errors='coerce').dropna()
        if len(s) > 0:
            print(f"{stype}: max ${s.max()/1e6:.1f}M on {s.idxmax().strftime('%Y-%m-%d')}, {len(s)} obs, final ${s.iloc[-1]/1e6:.2f}M on {s.index[-1].strftime('%Y-%m-%d')}")
    except KeyError:
        pass
# Out:
# Total Outstanding: max $258.0M on 1880-01-31, 177 obs, final $27.95M on 1891-08-31
# Public Holdings: max $258.0M on 1880-01-31, 177 obs, final $27.95M on 1891-08-31

# %% [markdown]
# ## Secondary Market Price
#
# The 4.5% Loan's price history demonstrates several important features of Gilded Age bond markets:
#
# 1. **Stable premium through the early 1880s:** Prices held in a narrow \$110–\$116 range from 1879 through 1887, reflecting the bond's role as a benchmark high-grade sovereign instrument.
# 2. **Gradual decline from 1887–1891:** As the redemption date approached, prices converged toward par — a classic "pull-to-par" effect observed in bonds that are expected to be called or redeemed.
# 3. **September 1891 trough (\$99.50):** Prices briefly dipped below par as the imminent refunding overhang weighed on valuations.
# 4. **Quarterly coupon premium:** The quarterly-coupon structure was attractive to trustees and endowments managing regular disbursement schedules. This likely contributed to the bond's sustained premium over most of its life.

# %%
fig, ax = plt.subplots(figsize=(14, 7))

try:
    s = BondPrice_T.loc[(20120, 'Average')]
    s = pd.to_numeric(s, errors='coerce').dropna().sort_index()
except KeyError:
    s = pd.Series(dtype=float)

if len(s) > 0:
    ax.plot(s.index, s.values, marker='.', markersize=5, linewidth=2,
            color='#2c3e50', label='Average Price', zorder=5)
    ax.axhline(100, color='black', alpha=0.3, linestyle='--', linewidth=1.5, label='Par ($100)')

    ax.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6', label='Panic of 1873 / Long Depression')
    pmin_d, pmin_v = s.idxmin(), s.min()
    pmax_d, pmax_v = s.idxmax(), s.max()
    ax.annotate(f'LOW: ${pmin_v:.2f}\n({pmin_d.strftime("%b %Y")})',
                xy=(pmin_d, pmin_v), xytext=(30, -35),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#c0392b',
                arrowprops=dict(arrowstyle='->', color='#c0392b', lw=1.2))
    ax.annotate(f'HIGH: ${pmax_v:.2f}\n({pmax_d.strftime("%b %Y")})',
                xy=(pmax_d, pmax_v), xytext=(30, 20),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#27ae60',
                arrowprops=dict(arrowstyle='->', color='#27ae60', lw=1.2))
    ax.set_title('Four and One-Half Percent Loan of 1891 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date'); ax.set_ylabel('Price ($)')
    ax.legend(loc='lower left', fontsize=9, framealpha=0.9)
    ax.grid(True, alpha=0.3)

    print(f"Price Statistics ({len(s)} obs):")
    print(f"  Mean ${s.mean():.2f} | Std ${s.std():.2f} | Range ${s.min():.2f}-${s.max():.2f}")
    print(f"  First obs: {s.index.min().strftime('%Y-%m-%d')} | Last obs: {s.index.max().strftime('%Y-%m-%d')}")
else:
    ax.text(0.5, 0.5, 'No secondary-market price series is recorded\nfor this bond in the Hall-Payne-Sargent database.',
            transform=ax.transAxes, ha='center', va='center', fontsize=14,
            bbox=dict(boxstyle='round,pad=0.5', fc='#fef9e7', ec='#f39c12'))
    ax.set_title('Four and One-Half Percent Loan of 1891 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xticks([]); ax.set_yticks([])

plt.tight_layout()
plt.show()
# Out:
# Price Statistics (181 obs):
#   Mean $108.89 | Std $4.07 | Range $99.50-$116.00
#   First obs: 1876-09-30 | Last obs: 1891-09-30

# %% [markdown]
# ## Price and Quantity Together

# %%
fig, ax1 = plt.subplots(figsize=(14, 6))

ax1.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6')
for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        q = BondQuant_T.loc[(20120, stype)]
        q = q[q.notna()].sort_index()
        if len(q) > 0:
            ax1.fill_between(q.index, q.values / 1e6, alpha=0.2, color='#3498db')
            ax1.plot(q.index, q.values / 1e6, color='#3498db', alpha=0.8,
                     linewidth=1.5, label=f'Quantity ({stype})')
            break
    except KeyError:
        pass

ax1.set_xlabel('Date')
ax1.set_ylabel('Quantity Outstanding ($ millions)', color='#3498db')
ax1.tick_params(axis='y', labelcolor='#3498db')

ax2 = ax1.twinx()
try:
    p = BondPrice_T.loc[(20120, 'Average')]
    p = pd.to_numeric(p, errors='coerce').dropna().sort_index()
    if len(p) > 0:
        ax2.plot(p.index, p.values, color='#e74c3c', marker='.', markersize=3,
                 linewidth=2, label='Average Price')
        ax2.axhline(100, color='gray', alpha=0.3, linestyle='--')
        ax2.set_ylabel('Price ($)', color='#e74c3c')
        ax2.tick_params(axis='y', labelcolor='#e74c3c')
except KeyError:
    pass

ax1.set_title('Four and One-Half Percent Loan of 1891 — Price and Quantity Together', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right', fontsize=9, framealpha=0.9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Volatility & Drawdown

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 8), gridspec_kw={'height_ratios': [2, 1]})

try:
    p = BondPrice_T.loc[(20120, 'Average')]
    p = pd.to_numeric(p, errors='coerce').dropna().sort_index()
except KeyError:
    p = pd.Series(dtype=float)

ax = axes[0]
if len(p) > 0:
    ax.plot(p.index, p.values, color='#2c3e50', linewidth=2, label='Price')
    ax.axhline(100, color='black', alpha=0.2, linestyle='--')
    running_max = p.expanding().max()
    ax.fill_between(p.index, p.values, running_max.values, alpha=0.3,
                    color='#e74c3c', label='Drawdown from Peak')
    ax.set_title('Price and Drawdown from Peak', fontsize=13, fontweight='bold')
    ax.set_ylabel('Price ($)'); ax.legend(fontsize=9); ax.grid(True, alpha=0.3)
else:
    ax.text(0.5, 0.5, 'No price series available', transform=ax.transAxes, ha='center', fontsize=12)

ax2 = axes[1]
if len(p) >= 12:
    rolling_std = p.rolling(window=12).std().dropna()
    ax2.fill_between(rolling_std.index, rolling_std.values, alpha=0.4, color='#e74c3c')
    ax2.plot(rolling_std.index, rolling_std.values, color='#c0392b', linewidth=1.5)
ax2.set_title('12-Month Rolling Price Volatility (Std Dev)', fontsize=13, fontweight='bold')
ax2.set_xlabel('Date'); ax2.set_ylabel('Std Dev ($)'); ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

if len(p) > 0:
    dd = (p.min() - p.max()) / p.max() * 100
    print(f"\nMaximum drawdown from rolling peak: {dd:.1f}%")
    print(f"  Peak ${p.max():.2f} on {p.idxmax().strftime('%Y-%m-%d')}")
    print(f"  Trough ${p.min():.2f} on {p.idxmin().strftime('%Y-%m-%d')}")
# Out:
# Maximum drawdown from rolling peak: -14.2%
#   Peak $116.00 on 1882-04-30
#   Trough $99.50 on 1891-09-30

# %% [markdown]
# ## Connections
#
# - {ref}`bond-20121-four-percent-loan-of-1907` — **4 Percent Loan of 1907** (Bond ID 20121). Sister refunding bond under the same Act of July 14, 1870.
# - {ref}`bond-20114-consols-of-1865` — **Consols of 1865** (Bond ID 20114). Underlying 6% obligation that this Loan refinanced.
# - {ref}`bond-20101-five-twenties-of-1862` — **Five-Twenties of 1862** (Bond ID 20101). Earliest of the Civil War 6% bonds whose long retirement this Loan completed.

# %% [markdown]
# ## Legacy and Significance
#
# ### The Shift to a Gold-Standard Bond Market
#
# The 4.5% Loan of 1891 was part of a broader transformation of American sovereign debt markets. Before specie resumption (January 1, 1879), U.S. Treasury bonds had carried a **gold-risk premium** reflecting uncertainty about whether the government would actually honor its coin-redemption promises. After resumption, that premium largely disappeared. The 4.5% Loan was among the first major Treasury issues placed **entirely under the restored gold standard** — its quarterly coupons and mid-term maturity made it a natural instrument for European investors now returning to American markets.
#
# ### Interest Savings
#
# The economic savings from refunding were substantial. A \$258 million bond at 4.5% pays \$11.61 million in annual interest. The same \$258 million at the old 6% coupon (the Civil War rate) would have paid \$15.48 million — a difference of \$3.87 million per year. Over the 15-year life of the bond, the Treasury saved close to \$60 million in interest costs on this single issue alone — and the 4% Loan of 1907 saved considerably more.
#
# ### Quarterly Coupons
#
# The 4.5% Loan was one of the first U.S. Treasury bonds to use **quarterly rather than semi-annual coupons**. This feature, borrowed from European practice, was designed to match the cash-flow needs of savings institutions and trustees. It also made the effective yield calculation more intuitive (annual yield = 4 × quarterly coupon). The quarterly feature was continued in the 4% Loan of 1907 but was not universally adopted — most later Treasury bonds reverted to semi-annual payments. Today, all U.S. Treasury notes and bonds pay semi-annual coupons.

# %% [markdown]
# ## References
#
# - Payne, J., Szoke, A., Hall, G. & Sargent, T. (2025). *Hall-Payne-Sargent US Federal Bond Database.*
# - Bayley, R. A. (1881). *The National Loans of the United States, 1776–1880.*
# - Sherman, John (1895). *John Sherman's Recollections of Forty Years in the House, Senate, and Cabinet.* Werner.
# - Dewey, D. R. (1918). *Financial History of the United States.*
# - Studenski, P. & Krooss, H. E. (1952). *Financial History of the United States.*
# - Friedman, M. & Schwartz, A. J. (1963). *A Monetary History of the United States.*
# - Unger, I. (1964). *The Greenback Era.*
# - Timberlake, R. H. (1993). *Monetary Policy in the United States: An Intellectual and Institutional History.* University of Chicago Press.
#
# ### Primary Source — Bayley (1881)
#
# - **Bayley, R. A.** (1881). *The National Loans of the United States, From July 4, 1776, to June 30, 1880.* Washington: Government Printing Office, ch. 4 ("Funded Loans of 1881, 1891, and 1907"). Digital MyST edition: see the companion `bayley-myst/` project.
