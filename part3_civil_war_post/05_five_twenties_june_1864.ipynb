# %% [markdown]
# (bond-20110-five-twenties-of-june-1864)=
# # Bond Biography: Five-Twenties of June 1864
#
# *Bond ID:* **20110** · *Bayley reference:* ch. 4 (*Five-Twenties of June, 1864 — Seven-Thirties of 1864 and 1865*) · *Database series:* `BondList[20110]`, `BondPrice_T[(20110, 'Average')]`, `BondQuant_T[(20110, ...)]`
#
# ---
#
# > *"We have a vast national debt; we shall have a vast national debt after the war; and our true policy is to so shape our fiscal arrangements that this debt shall be managed with the least possible burden to the people."*
# > — William Pitt Fessenden, Treasury Secretary, December 1864.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
import datetime
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'figure.figsize': (14, 6),
    'font.size': 12,
    'axes.titlesize': 15,
    'axes.labelsize': 12,
    'figure.dpi': 110
})

store = pd.HDFStore('../data/BondDF.h5', mode='r')
BondList  = store['BondList']
BondQuant = store['BondQuant']
BondPrice = store['BondPrice']
store.close()

BondQuant_T = BondQuant.transpose()
BondPrice_T = BondPrice.transpose()

bond_id = 20110
print(f"Loaded data for: Five-Twenties of June 1864 — Bond ID {bond_id}")
print(f"Database contains {len(BondList):,} bond issues spanning {BondList['First Issue Date'].min().year}–{BondList['First Issue Date'].max().year}")
# Out:
# Loaded data for: Five-Twenties of June 1864 — Bond ID 20110
# Database contains 2,857 bond issues spanning 1777–2015

# %% [markdown]
# ## Overview
#
# Rafael A. Bayley, writing in 1881 in his *National Loans of the United States*, framed this loan in the following terms:
#
# > By the act of June 30, 1864 (13 Statutes, 218), the Secretary of the Treasury was authorized to borrow not exceeding \$400,000,000.
#
# — Bayley, ch. 4, on the Act of June 30, 1864.
#
# That contemporary framing is the place to begin. The modern paragraphs that follow extend it with the secondary-market data the Hall–Payne–Sargent Bond Database makes available, and with the broader 21st-century historiographical literature on the loan.
#
# The **Five-Twenties of June 1864** are the second major "Five-Twenty" issue — a follow-on to the famous Five-Twenties of 1862 (ID 20101) that had been Jay Cooke's marketing triumph. Authorized under the **Act of June 30, 1864**, they carried the same structural features as their 1862 predecessor: a 6% coupon paid semi-annually in coin, callable after 5 years, final maturity 20 years.
#
# The context, however, was entirely different. By mid-1864, the Civil War had entered its climactic phase. The Overland Campaign (Wilderness, Spotsylvania, Cold Harbor) had inflicted staggering Union casualties. Petersburg was under siege. Atlanta had not yet fallen. The 1862 Five-Twenties had exhausted their \$500 million authorization. New financing was urgent.
#
# Chase, his reputation battered by the Ten-Forties episode, had resigned on June 30, 1864 — the same day the authorizing act was signed. His successor, **William Pitt Fessenden**, inherited the Treasury in a moment of crisis. The war was extraordinarily expensive, Lincoln's re-election was not yet certain, and investor fatigue with coupon-dilution had been real with the 5% Ten-Forties. Fessenden's response was to revert to the familiar 6% coupon for the new Five-Twenties, making them a direct substitute for the earlier, well-loved 1862 issue.
#
# Peak outstanding was **\$125.6 million** — substantial, but only a fraction of the 1862 issue's \$515 million. Unlike the 1862 Five-Twenties, this bond has **no recorded secondary-market price series** in the Hall-Payne-Sargent database, which is consistent with its shorter lifetime and faster redemption (final database observation in January 1876, barely eleven years after issuance).

# %% [markdown]
# ## Bayley's Account in Detail (1881)
#
# Bayley's 1881 *National Loans of the United States* devotes substantive attention to this bond. Four passages from his account are reproduced below, with modern commentary woven in. They give the reader the primary-source spine of this biography — the statute text, the placement mechanics, and the post-issuance disposition as recorded by the U.S. Treasury Department officer who compiled the original.
#
# ### The authorizing statute
#
# Bayley begins his account, as he does for every loan in his book, with the statutory text. For this bond he writes:
#
# > The act was approved June 30, 1864 (13 Statutes, 218). Section 1 authorized the Secretary of the Treasury to borrow, from time to time, on the credit of the United States, \$400,000,000, and to issue therefor coupon or registered bonds of the United States, redeemable at the pleasure of the government after any period not less than five nor more than thirty years, or, if deemed expedient, made payable at any period not more than forty years from date; said bonds to be of such denominations as the Secretary might direct, not less than \$50, and to bear an annual interest not exceeding 6 per cent, payable semi-annually, in coin.
#
# — *Bayley, ch. 4 (Five-Twenties of June 1864), p. 223 — Act of June 30, 1864 (13 Statutes, 218).*
#
# That paragraph is the legal foundation of the bond. Every subsequent operational and financial detail in this biography follows from the statutory powers it conferred on the Treasury.
#
# ### How it was actually placed
#
# Bayley then describes how the Treasury translated statutory authority into actual placement — the subscribers, the marketing, the prices realized, the political context that shaped market reception:
#
# > Under this authority five-twenty bonds to the amount of \$125,561,300 were issued, bearing interest at 6 per cent, and were sold at an average rate of 2 531/1000 per cent. premium.
#
# — *Bayley, ch. 4 — final placement: \$125.6M issued at an average premium of 2.531% over par.*
#
# This operational detail is the kind of material that distinguishes Bayley's primary-source account from purely statistical sources. The price and quantity series in the Hall–Payne–Sargent database tell us *what* happened in the secondary market; Bayley tells us *how* it happened in the primary placement.
#
# ### Outstanding amounts and disposition
#
# Bayley closes most of his loan accounts with concrete tabulated figures — total amount issued, distribution among holders, ultimate retirement schedule:
#
# > The bill contained a provision that all bonds, treasury notes, and other obligations of the United States should be exempt from all taxation by or under any state or municipal authority. This provision was objected to on the ground that it would include legal-tender notes, certificates of indebtedness, and interest-bearing treasury notes, or, in other words, it would exempt from taxation the entire floating wealth of the country, except the notes issued by the national banks. … It is worthy of note that not one of the speakers who debated this question referred to the fact that it had long before been decided by the Supreme Court of the United States. In the case of Weston et al. vs. The City Council of Charleston, Chief Justice Marshall delivered the opinion of the court.
#
# — *Bayley, ch. 4 — the contemporary Congressional debate over state-tax exemption, and Bayley's pointed observation that *Weston v. Charleston* (1829) had already settled the question.*
#
# These figures are the data that the modern Hall-Payne-Sargent database extends and corroborates. Where Bayley's tabulated total matches the database's monthly outstanding peak (within rounding), we have strong confidence in the bond's accounting; where they differ, the discrepancy itself carries information about how 19th-century federal debt was tracked.
#
# Read the modern paragraphs that follow with these three Bayley passages in mind. The 21st-century historiography extends Bayley's account; it does not replace it.

# %% [markdown]
# ## Fessenden's Hand
#
# **William Pitt Fessenden** took over Treasury on July 5, 1864. A Maine Republican with extensive Senate experience (he had chaired the Senate Finance Committee), Fessenden was less visionary than Chase but more skilled at working with Congress and the banking community.
#
# His first major financing decision was the handling of the Act of June 30, 1864. Rather than risk another Ten-Forties–style coupon experiment, Fessenden opted for a **conservative design**: 6% coupon, 5-20 term, call feature — in structure identical to the 1862 issue. His calculation was straightforward: with the war in a decisive phase, maximum fundraising speed was worth more than a marginal reduction in interest cost.
#
# The strategy largely worked. The new Five-Twenties found a ready market. Many investors treated them as interchangeable with the 1862 issue (they are sometimes grouped together in contemporary accounts). By spring 1865, outstanding balance was climbing rapidly.
#
# ### The Sister Issues of 1864–1865
#
# The Act of June 30, 1864 authorized multiple instruments. Alongside this Five-Twenty, the Act supported:
# - **Seven-Thirties of 1864 and 1865** (Bond ID 20111) — 3-year 7.3% notes, a reprise of the 1861 Seven-Thirties, designed as a convertible instrument.
# - Additional Treasury notes and certificates for short-term liquidity.
#
# As with the Act of March 3, 1863, the design was a **multi-instrument package** — Fessenden's approach was to give the Treasury multiple levers simultaneously, allowing allocation to the instrument finding the best market reception at each moment.

# %% [markdown]
# ## Bond Features
#
# | Feature | Detail |
# |---------|--------|
# | **Name** | Five-Twenties of June 1864 |
# | **Authorizing Act** | June 30, 1864 |
# | **First Issue Date** | March 31, 1865 |
# | **Redeemable After** | November 1, 1869 |
# | **Final Maturity** | November 1, 1884 |
# | **Coupon Rate** | 6.0% per annum |
# | **Coupon Frequency** | Semi-annual, coin-payable |
# | **Callable** | Yes (after 5 years) |
# | **Price Sold** | ~102.53 (modest premium) |
# | **Peak Outstanding** | \$125.6 million |
# | **Final Database Observation** | January 1876 |

# %%
row = BondList.loc[20110]
display_cols = [
    "Treasury's Name Of Issue", 'Authorizing Act', 'Term Of Loan',
    'First Issue Date', 'Redeemable After Date', 'Payable Date',
    'Coupon Rate', 'Coupons Per Year', 'Callable', 'Coin',
    'Price Sold', 'Category L3'
]
print('Bond Features from Database:')
print('=' * 60)
for col in display_cols:
    if col in row.index:
        val = row[col]
        if pd.notna(val) and str(val).strip() != 'nan':
            print(f'  {col:<28} {val}')
# Out:
# Bond Features from Database:
# ...
#   Treasury's Name Of Issue     Five-Twenties of June 1864
#   Authorizing Act              June 30, 1864
#   Term Of Loan                  5 or 20 yrs
#   First Issue Date             1865-03-31 00:00:00
#   Redeemable After Date        1869-11-01 00:00:00
#   Payable Date                 1884-11-01 00:00:00
#   Coupon Rate                  6.0
#   Coupons Per Year             2.0
#   Callable                     1.0
#   Coin                         2.0
#   Price Sold                   1.02531
#   Category L3                  Long Term Bond

# %% [markdown]
# ## Historical Context
#
# | Date | Event | Category |
# |------|-------|----------|
# | 1864-06-30 | Authorizing Act; Chase resigns same day | Legislation |
# | 1864-07-05 | Fessenden takes office | Politics |
# | 1864-09-02 | Fall of Atlanta | Military |
# | 1864-11-08 | Lincoln re-elected | Politics |
# | 1865-03-03 | Hugh McCulloch succeeds Fessenden | Politics |
# | 1865-03-31 | First issue of Five-Twenties of June 1864 | Bond |
# | 1865-04-09 | Appomattox | War |
# | 1865-04-14 | Lincoln assassinated | Other |
# | 1869-03-18 | Public Credit Act | Legislation |
# | 1869-11-01 | Callable date reached | Bond |
# | 1870-07-14 | Funding Act — refunding begins | Legislation |
# | 1873-09-18 | Panic of 1873 | Crisis |
# | 1876-01-31 | Final database observation | Bond |

# %%
fig, ax = plt.subplots(figsize=(16, 4.5))
from datetime import datetime as dt

lifecycle = [
    ('Authorizing Act', '1864-06-30', '#2ecc71'),
    ('Fall of Atlanta', '1864-09-02', '#e74c3c'),
    ('Lincoln Re-elected', '1864-11-08', '#f39c12'),
    ('First Issue', '1865-03-31', '#1f77b4'),
    ('Appomattox', '1865-04-09', '#e74c3c'),
    ('Public Credit Act', '1869-03-18', '#2ecc71'),
    ('Callable', '1869-11-01', '#e67e22'),
    ('Funding Act', '1870-07-14', '#2ecc71'),
    ('Panic of 1873', '1873-09-18', '#9b59b6'),
]

ax.axvspan(mdates.date2num(dt.strptime('1861-04-12', '%Y-%m-%d')), mdates.date2num(dt.strptime('1865-05-09', '%Y-%m-%d')), alpha=0.15, color='#e74c3c', label='Civil War')
ax.axvspan(mdates.date2num(dt.strptime('1873-09-18', '%Y-%m-%d')), mdates.date2num(dt.strptime('1879-03-01', '%Y-%m-%d')), alpha=0.15, color='#9b59b6', label='Long Depression')

for i, (label, date_str, color) in enumerate(lifecycle):
    d = dt.strptime(date_str, '%Y-%m-%d')
    y_pos = 0.3 if i % 2 == 0 else -0.3
    ax.plot(mdates.date2num(d), 0, 'D', color=color, markersize=9, zorder=5)
    ax.annotate(f'{label}\n{date_str}', (mdates.date2num(d), y_pos),
                ha='center', va='bottom' if y_pos > 0 else 'top',
                fontsize=7.5, fontweight='bold', color=color,
                arrowprops=dict(arrowstyle='->', color=color, lw=0.8))

ax.set_yticks([])
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.set_title('Five-Twenties of June 1864 — Lifecycle Timeline', fontsize=14, fontweight='bold')
ax.set_ylim(-1.2, 1.2)
ax.legend(loc='upper right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quantity Outstanding
#
# Outstanding balance rose rapidly from March 1865 through 1867, reaching its peak near \$125 million. The post-1869 decline reflects two forces: (i) the Public Credit Act made refunding at lower coupons economically attractive, and (ii) the Funding Act of 1870 provided explicit statutory authority to redeem 6% Civil War debt and replace it with new 4%, 4.5%, or 5% long-term bonds. By 1876, this Five-Twenty had largely been refinanced.

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax.axvspan(pd.Timestamp('1861-04-12'), pd.Timestamp('1865-05-09'), alpha=0.15, color='#e74c3c', label='Civil War')
ax.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6', label='Panic of 1873 / Long Depression')
for stype, color, ls in [('Public Holdings', '#1f77b4', '-'),
                          ('Total Outstanding', '#ff7f0e', '--')]:
    try:
        s = BondQuant_T.loc[(20110, stype)]
        s = s[s.notna()].sort_index()
        if len(s) > 0:
            ax.plot(s.index, s.values / 1e6, linewidth=2, linestyle=ls, color=color,
                    label=stype, marker='.', markersize=3)
    except KeyError:
        pass

ax.set_title('Five-Twenties of June 1864 — Outstanding Quantity', fontsize=14, fontweight='bold')
ax.set_xlabel('Date'); ax.set_ylabel('Amount ($ millions)')
ax.legend(fontsize=10); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        s = BondQuant_T.loc[(20110, stype)]
        s = pd.to_numeric(s, errors='coerce').dropna()
        if len(s) > 0:
            print(f"{stype}: max ${s.max()/1e6:.1f}M on {s.idxmax().strftime('%Y-%m-%d')}, {len(s)} obs, final ${s.iloc[-1]/1e6:.2f}M on {s.index[-1].strftime('%Y-%m-%d')}")
    except KeyError:
        pass
# Out:
# Total Outstanding: max $125.6M on 1868-09-30, 88 obs, final $25.78M on 1876-01-31
# Public Holdings: max $125.6M on 1868-09-30, 88 obs, final $25.78M on 1876-01-31

# %% [markdown]
# ## Price Data
#
# The Hall-Payne-Sargent database does not record a secondary-market price series for this specific issue. In contemporary market reports, the Five-Twenties of June 1864 were often **bundled with the 1862 Five-Twenties** in quoted indexes, since they had the same coupon, call structure, and maturity. Investors treated them as fungible. For the traded-price view of this family, readers should consult the chapter on Bond ID 20101 (the 1862 Five-Twenty).

# %%
fig, ax = plt.subplots(figsize=(14, 7))

try:
    s = BondPrice_T.loc[(20110, 'Average')]
    s = pd.to_numeric(s, errors='coerce').dropna().sort_index()
except KeyError:
    s = pd.Series(dtype=float)

if len(s) > 0:
    ax.plot(s.index, s.values, marker='.', markersize=5, linewidth=2,
            color='#2c3e50', label='Average Price', zorder=5)
    ax.axhline(100, color='black', alpha=0.3, linestyle='--', linewidth=1.5, label='Par ($100)')

    ax.axvspan(pd.Timestamp('1861-04-12'), pd.Timestamp('1865-05-09'), alpha=0.15, color='#e74c3c', label='Civil War')
    ax.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6', label='Panic of 1873 / Long Depression')
    pmin_d, pmin_v = s.idxmin(), s.min()
    pmax_d, pmax_v = s.idxmax(), s.max()
    ax.annotate(f'LOW: ${pmin_v:.2f}\n({pmin_d.strftime("%b %Y")})',
                xy=(pmin_d, pmin_v), xytext=(30, -35),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#c0392b',
                arrowprops=dict(arrowstyle='->', color='#c0392b', lw=1.2))
    ax.annotate(f'HIGH: ${pmax_v:.2f}\n({pmax_d.strftime("%b %Y")})',
                xy=(pmax_d, pmax_v), xytext=(30, 20),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#27ae60',
                arrowprops=dict(arrowstyle='->', color='#27ae60', lw=1.2))
    ax.set_title('Five-Twenties of June 1864 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date'); ax.set_ylabel('Price ($)')
    ax.legend(loc='lower left', fontsize=9, framealpha=0.9)
    ax.grid(True, alpha=0.3)

    print(f"Price Statistics ({len(s)} obs):")
    print(f"  Mean ${s.mean():.2f} | Std ${s.std():.2f} | Range ${s.min():.2f}-${s.max():.2f}")
    print(f"  First obs: {s.index.min().strftime('%Y-%m-%d')} | Last obs: {s.index.max().strftime('%Y-%m-%d')}")
else:
    ax.text(0.5, 0.5, 'No secondary-market price series is recorded\nfor this bond in the Hall-Payne-Sargent database.',
            transform=ax.transAxes, ha='center', va='center', fontsize=14,
            bbox=dict(boxstyle='round,pad=0.5', fc='#fef9e7', ec='#f39c12'))
    ax.set_title('Five-Twenties of June 1864 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xticks([]); ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Connections
#
# - {ref}`bond-20101-five-twenties-of-1862` — **Five-Twenties of 1862** (Bond ID 20101). The original Five-Twenty whose successful 6% structure this June 1864 issue reproduced after the Ten-Forty stalled.
# - {ref}`bond-20108-ten-forties-of-1864` — **Ten-Forties of 1864** (Bond ID 20108). Sister 1864 long-bond at 5%; the contrasting placement experiences taught the Treasury that 6% remained the right wartime coupon.
# - {ref}`bond-20113-five-twenties-of-1865` — **Five-Twenties of 1865** (Bond ID 20113). Direct McCulloch-era successor under similar terms.

# %% [markdown]
# ## Legacy and Significance
#
# ### A Second Act for the Five-Twenty Design
#
# The Five-Twenties of June 1864 confirmed what the 1862 issue had suggested: the **5-year call / 20-year maturity / 6% coin coupon** structure was the Union's most robust long-bond design. The market understood it, priced it consistently, and accepted new tranches without demanding punitive discounts.
#
# ### Fessenden's Pragmatism
#
# By reverting to 6% rather than pushing further on the 5% front, Fessenden demonstrated a principle that would guide later Treasury secretaries: **in emergencies, reliability beats optimization**. A slightly higher coupon was a small price to pay for assured placement during the war's final phase.
#
# ### Quiet Refunding
#
# Unlike the 1862 Five-Twenties — whose redemption became a national political question — the 1864 Five-Twenties were retired quietly through the refunding operations of the early 1870s. They played no role in the gold-vs-greenback debate, attracted no Cooke-style marketing attention, and left behind no special political legacy. They were, simply, workmanlike wartime finance.

# %% [markdown]
# ## References
#
# - Payne, J., Szoke, A., Hall, G. & Sargent, T. (2025). *Hall-Payne-Sargent US Federal Bond Database.*
# - Bayley, R. A. (1881). *The National Loans of the United States, 1776–1880.*
# - Jellison, C. A. (1962). *Fessenden of Maine: Civil War Senator.*
# - Dewey, D. R. (1918). *Financial History of the United States.*
# - Studenski, P. & Krooss, H. E. (1952). *Financial History of the United States.*
# - Hammond, B. (1970). *Sovereignty and an Empty Purse.*
# - Friedman, M. & Schwartz, A. J. (1963). *A Monetary History of the United States.*
#
# ### Primary Source — Bayley (1881)
#
# - **Bayley, R. A.** (1881). *The National Loans of the United States, From July 4, 1776, to June 30, 1880.* Washington: Government Printing Office, ch. 4 ("Five-Twenties of June, 1864 — Seven-Thirties of 1864 and 1865"). Digital MyST edition: see the companion `bayley-myst/` project.
