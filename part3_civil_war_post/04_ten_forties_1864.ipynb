# %% [markdown]
# (bond-20108-ten-forties-of-1864)=
# # Bond Biography: Ten-Forties of 1864
#
# *Bond ID:* **20108** · *Bayley reference:* ch. 4 (*Ten-Forties of 1864 — Five-Twenties of March, 1864*) · *Database series:* `BondList[20108]`, `BondPrice_T[(20108, 'Average')]`, `BondQuant_T[(20108, ...)]`
#
# ---
#
# > *"The public mind is familiar with the idea of long loans at low rates, and the time is ripe for the experiment."*
# > — Salmon P. Chase, testimony before the House Ways and Means Committee, early 1864 (paraphrase).
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
import datetime
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'figure.figsize': (14, 6),
    'font.size': 12,
    'axes.titlesize': 15,
    'axes.labelsize': 12,
    'figure.dpi': 110
})

store = pd.HDFStore('../data/BondDF.h5', mode='r')
BondList  = store['BondList']
BondQuant = store['BondQuant']
BondPrice = store['BondPrice']
store.close()

BondQuant_T = BondQuant.transpose()
BondPrice_T = BondPrice.transpose()

bond_id = 20108
print(f"Loaded data for: Ten-Forties of 1864 — Bond ID {bond_id}")
print(f"Database contains {len(BondList):,} bond issues spanning {BondList['First Issue Date'].min().year}–{BondList['First Issue Date'].max().year}")
# Out:
# Loaded data for: Ten-Forties of 1864 — Bond ID 20108
# Database contains 2,857 bond issues spanning 1777–2015

# %% [markdown]
# ## Overview
#
# Rafael A. Bayley, writing in 1881 in his *National Loans of the United States*, framed this loan in the following terms:
#
# > By the act of March 3, 1864 (13 Statutes, 13), an additional \$200,000,000 was authorized, in bonds redeemable after ten and payable in forty years, bearing not exceeding 6 per cent. interest, payable semi-annually, in coin.
#
# — Bayley, ch. 4, on the Act of March 3, 1864.
#
# That contemporary framing is the place to begin. The modern paragraphs that follow extend it with the secondary-market data the Hall–Payne–Sargent Bond Database makes available, and with the broader 21st-century historiographical literature on the loan.
#
# The **Ten-Forties of 1864** are an unusual — and in some ways tragic — instrument. They were Secretary **Salmon P. Chase's** most ambitious attempt to lower the Treasury's borrowing costs, and in a narrow technical sense they accomplished that goal: they carried a **5% coupon**, well below the 6% rate that had dominated Union long-term finance since 1861. But the lower coupon proved, at least initially, **too aggressive for the market**. When the bonds were offered at par in the spring of 1864, sales were sluggish. Chase was forced to rely on extraordinary measures — including the personal intervention of Jay Cooke — and, ultimately, to resign.
#
# His successor, **William Pitt Fessenden**, took over the Treasury on July 5, 1864. Fessenden, the former chairman of the Senate Finance Committee, had a deeper relationship with Congress than Chase and proved more flexible in managing wartime debt. Under Fessenden, the Ten-Forties were successfully placed — though at roughly \$195 million they came in well below the original hopes. His successor, **Hugh McCulloch**, would complete the placement and supervise the secondary-market stabilization of the 1865–1866 period.
#
# The bond's name — "Ten-Forties" — refers to its unusual call/maturity structure: **callable after 10 years, final maturity at 40 years**. This was an attempt to offer the Treasury long-run option value while still giving investors a clear horizon. The extended maturity, unusual for the time, reflected Chase's belief that post-war refinancing opportunities would make the 40-year endpoint largely theoretical.
#
# In the Hall-Payne-Sargent database, the Ten-Forties trade through **174 monthly price observations** spanning August 1864 to April 1879. Mean price: **\$107.68**. Range: **\$91.00** (November 1865, early postwar volatility) to **\$119.39** (January 1876, after substantial deflation and refunding announcements). Peak outstanding: **\$194.6 million**.

# %% [markdown]
# ## Bayley's Account in Detail (1881)
#
# Bayley's 1881 *National Loans of the United States* devotes substantive attention to this bond. Four passages from his account are reproduced below, with modern commentary woven in. They give the reader the primary-source spine of this biography — the statute text, the placement mechanics, and the post-issuance disposition as recorded by the U.S. Treasury Department officer who compiled the original.
#
# ### The authorizing statute
#
# Bayley begins his account, as he does for every loan in his book, with the statutory text. For this bond he writes:
#
# > Section 1 authorized the Secretary of the Treasury to borrow, from time to time, on the credit of the United States, not exceeding two hundred millions of dollars during the current fiscal year, and to prepare and issue therefor coupon or registered bonds of the United States, bearing date March 1, 1864, or any subsequent period, redeemable at the pleasure of the government after any period not less than five years, and payable at any period not more than forty years from date, in coin, and of such denominations as might be found expedient, not less than fifty dollars, bearing interest not exceeding six per centum a year.
#
# — *Bayley, ch. 4 (Ten-Forties of 1864), p. 214 — Act of March 3, 1864 (13 Statutes, 13).*
#
# That paragraph is the legal foundation of the bond. Every subsequent operational and financial detail in this biography follows from the statutory powers it conferred on the Treasury.
#
# ### How it was actually placed
#
# Bayley then describes how the Treasury translated statutory authority into actual placement — the subscribers, the marketing, the prices realized, the political context that shaped market reception:
#
# > Considerable debate ensued on the second section of the bill, which provided for an additional issue of \$11,000,000 to the \$500,000,000 already authorized by the act of March 3, 1863. The exigencies of the government required prompt action on the bill, and after a few slight amendments in the Senate it passed that body and was sent back to the House, where the amendments were adopted and the bill passed.
#
# — *Bayley, ch. 4 — the legislative passage in late February / early March 1864 (with an \$11M Five-Twenty supplement attached to the new Ten-Forty authorization).*
#
# This operational detail is the kind of material that distinguishes Bayley's primary-source account from purely statistical sources. The price and quantity series in the Hall–Payne–Sargent database tell us *what* happened in the secondary market; Bayley tells us *how* it happened in the primary placement.
#
# ### Outstanding amounts and disposition
#
# Bayley closes most of his loan accounts with concrete tabulated figures — total amount issued, distribution among holders, ultimate retirement schedule:
#
# > Under this act 5 per cent. interest-bearing bonds to the amount of \$196,118,300 were issued, redeemable after 10 and payable 40 years from date. Bonds to the amount of \$3,882,500, bearing interest at 6 per cent., redeemable in 5 and payable in 20 years, were also issued under the same authority. These latter have been generally known as the "Five-twenties of March, 1864".
#
# — *Bayley, ch. 4 — final issuance: \$196.1M in 5%/10-40 bonds (the Ten-Forties proper) plus \$3.9M of 6%/5-20 bonds (the "Five-Twenties of March 1864") authorized under the same act.*
#
# These figures are the data that the modern Hall-Payne-Sargent database extends and corroborates. Where Bayley's tabulated total matches the database's monthly outstanding peak (within rounding), we have strong confidence in the bond's accounting; where they differ, the discrepancy itself carries information about how 19th-century federal debt was tracked.
#
# Read the modern paragraphs that follow with these three Bayley passages in mind. The 21st-century historiography extends Bayley's account; it does not replace it.

# %% [markdown]
# ## The Coupon Controversy
#
# The most interesting feature of the Ten-Forties is how **nearly they failed**. Chase's hypothesis in proposing a 5% coupon was that the market had, by early 1864, accepted the government's credit and would accept a lower yield on long-dated securities. The hypothesis was half right.
#
# ### Initial Resistance
#
# When the Ten-Forties were first offered in the spring of 1864, investors **balked at the 5% coupon**. They had become used to 6% and, in the case of the Seven-Thirties, 7.3%. A 5% coupon felt like a concession just as the war was entering its most expensive phase (the Overland Campaign, the siege of Petersburg, Sherman's Atlanta campaign were all consuming cash at unprecedented rates).
#
# ### Cooke Declines the Call
#
# Jay Cooke, asked to handle brokerage, initially **declined to aggressively market the Ten-Forties at 5%** — a reversal from his Five-Twenty evangelism. Cooke privately concluded the coupon was too low and publicly marketing it would damage his credibility with subscribers.
#
# ### Chase's Resignation
#
# A combination of rising political friction with Lincoln (who had refused to accept Chase's earlier resignation threats as leverage), a tightening financial market, and the Ten-Forties' weak reception led Chase to submit his resignation on **June 30, 1864**. This time, Lincoln accepted. Fessenden took over on July 5.
#
# ### Fessenden's Rescue
#
# Under Fessenden, the Ten-Forties were still offered at 5%, but placement was coupled with other instruments (notably the Five-Twenties of June 1864 at 6% and the Seven-Thirties of 1864 at 7.3%). The combined offering allowed investors to blend coupon risk across different issues. By year-end 1864, the Ten-Forties had found their market — helped significantly by the military momentum of Atlanta's fall (September 2, 1864) and Lincoln's re-election (November 8, 1864).

# %% [markdown]
# ## Bond Features
#
# | Feature | Detail |
# |---------|--------|
# | **Name** | Ten-Forties of 1864 |
# | **Authorizing Act** | March 3, 1864 |
# | **First Issue Date** | December 31, 1864 |
# | **Redeemable After** | March 1, 1874 (10 years from authorization) |
# | **Final Maturity** | March 1, 1904 (40 years from authorization) |
# | **Coupon Rate** | 5.0% per annum |
# | **Coupon Frequency** | Semi-annual, coin-payable |
# | **Callable** | Yes, after 10 years |
# | **Price Sold** | Par (\$100) |
# | **Peak Outstanding** | \$194.6 million (mid-1870s) |

# %%
row = BondList.loc[20108]
display_cols = [
    "Treasury's Name Of Issue", 'Authorizing Act', 'Term Of Loan',
    'First Issue Date', 'Redeemable After Date', 'Payable Date',
    'Coupon Rate', 'Coupons Per Year', 'Callable', 'Coin',
    'Price Sold', 'Category L3'
]
print('Bond Features from Database:')
print('=' * 60)
for col in display_cols:
    if col in row.index:
        val = row[col]
        if pd.notna(val) and str(val).strip() != 'nan':
            print(f'  {col:<28} {val}')
# Out:
# Bond Features from Database:
# ...
#   Treasury's Name Of Issue     Ten-Forties of 1864
#   Authorizing Act              March 3, 1864
#   Term Of Loan                  10 or 40 yr
#   First Issue Date             1864-12-31 00:00:00
#   Redeemable After Date        1874-03-01 00:00:00
#   Payable Date                 1904-03-01 00:00:00
#   Coupon Rate                  5.0
#   Coupons Per Year             2.0
#   Callable                     1.0
#   Coin                         1.0
#   Price Sold                   1.0
#   Category L3                  Long Term Bond

# %% [markdown]
# ## Historical Context
#
# | Date | Event | Category |
# |------|-------|----------|
# | 1864-03-03 | Authorizing Act passed | Legislation |
# | 1864-06-30 | Chase resigns | Politics |
# | 1864-07-05 | Fessenden becomes Treasury Secretary | Politics |
# | 1864-09-02 | Fall of Atlanta | Military |
# | 1864-11-08 | Lincoln re-elected | Politics |
# | 1864-12-31 | First issue of Ten-Forties | Bond |
# | 1865-03-03 | Hugh McCulloch succeeds Fessenden | Politics |
# | 1865-04-09 | Appomattox | War |
# | 1869-03-18 | Public Credit Act — gold redemption mandated | Legislation |
# | 1870-07-14 | Funding Act — refunding at 4%, 4.5%, 5% | Legislation |
# | 1873-09-18 | Panic of 1873 | Crisis |
# | 1874-03-01 | First callable date | Bond |
# | 1879-03-01 | Final data observation per database | Bond |

# %%
fig, ax = plt.subplots(figsize=(16, 4.5))
from datetime import datetime as dt

lifecycle = [
    ('Authorizing Act', '1864-03-03', '#2ecc71'),
    ('Chase Resigns', '1864-06-30', '#f39c12'),
    ('Fall of Atlanta', '1864-09-02', '#e74c3c'),
    ('First Issue', '1864-12-31', '#1f77b4'),
    ('Appomattox', '1865-04-09', '#e74c3c'),
    ('Public Credit Act', '1869-03-18', '#2ecc71'),
    ('Funding Act', '1870-07-14', '#2ecc71'),
    ('Panic of 1873', '1873-09-18', '#9b59b6'),
    ('Callable', '1874-03-01', '#e67e22'),
]

ax.axvspan(mdates.date2num(dt.strptime('1861-04-12', '%Y-%m-%d')), mdates.date2num(dt.strptime('1865-05-09', '%Y-%m-%d')), alpha=0.15, color='#e74c3c', label='Civil War')
ax.axvspan(mdates.date2num(dt.strptime('1873-09-18', '%Y-%m-%d')), mdates.date2num(dt.strptime('1879-03-01', '%Y-%m-%d')), alpha=0.15, color='#9b59b6', label='Long Depression')

for i, (label, date_str, color) in enumerate(lifecycle):
    d = dt.strptime(date_str, '%Y-%m-%d')
    y_pos = 0.3 if i % 2 == 0 else -0.3
    ax.plot(mdates.date2num(d), 0, 'D', color=color, markersize=9, zorder=5)
    ax.annotate(f'{label}\n{date_str}', (mdates.date2num(d), y_pos),
                ha='center', va='bottom' if y_pos > 0 else 'top',
                fontsize=7.5, fontweight='bold', color=color,
                arrowprops=dict(arrowstyle='->', color=color, lw=0.8))

ax.set_yticks([])
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.set_title('Ten-Forties of 1864 — Lifecycle Timeline', fontsize=14, fontweight='bold')
ax.set_ylim(-1.2, 1.2)
ax.legend(loc='upper right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quantity Outstanding
#
# Outstanding balance rose steadily from issuance through the late 1860s, peaking near \$195 million, and then remained stable until the Funding Act of 1870 began the refunding process. Note that the final database observation (April 1879) shows outstanding still above \$138 million — consistent with a bond whose final maturity was 1904 and whose call feature (available after 1874) was exercised selectively based on refinancing rates.

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax.axvspan(pd.Timestamp('1861-04-12'), pd.Timestamp('1865-05-09'), alpha=0.15, color='#e74c3c', label='Civil War')
ax.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6', label='Panic of 1873 / Long Depression')
for stype, color, ls in [('Public Holdings', '#1f77b4', '-'),
                          ('Total Outstanding', '#ff7f0e', '--')]:
    try:
        s = BondQuant_T.loc[(20108, stype)]
        s = s[s.notna()].sort_index()
        if len(s) > 0:
            ax.plot(s.index, s.values / 1e6, linewidth=2, linestyle=ls, color=color,
                    label=stype, marker='.', markersize=3)
    except KeyError:
        pass

ax.set_title('Ten-Forties of 1864 — Outstanding Quantity', fontsize=14, fontweight='bold')
ax.set_xlabel('Date'); ax.set_ylabel('Amount ($ millions)')
ax.legend(fontsize=10); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        s = BondQuant_T.loc[(20108, stype)]
        s = pd.to_numeric(s, errors='coerce').dropna()
        if len(s) > 0:
            print(f"{stype}: max ${s.max()/1e6:.1f}M on {s.idxmax().strftime('%Y-%m-%d')}, {len(s)} obs, final ${s.iloc[-1]/1e6:.2f}M on {s.index[-1].strftime('%Y-%m-%d')}")
    except KeyError:
        pass
# Out:
# Total Outstanding: max $194.6M on 1868-09-30, 131 obs, final $138.43M on 1879-06-30
# Public Holdings: max $194.6M on 1868-09-30, 131 obs, final $138.43M on 1879-06-30

# %% [markdown]
# ## Secondary Market Price
#
# The Ten-Forties' price history is a revealing window into the post-war bond market:
#
# 1. **1864–1865 Low (\$91):** Initial skepticism about the 5% coupon, confounded by general market turbulence at war's end.
# 2. **1866–1868 Recovery:** Prices climbed toward \$110 as the war ended and sovereign credibility improved.
# 3. **1869 Public Credit Act:** Prices spiked further as the gold-redemption question was resolved favorably.
# 4. **1876 Peak (\$119):** Post-deflation environment with 5% coupon increasingly attractive relative to falling market rates; refunding rumors also supported prices.
# 5. **1873–1879 Volatility:** The Panic of 1873 and Long Depression produced intermittent selling pressure, but the bonds never retraced to their pre-1869 lows.

# %%
fig, ax = plt.subplots(figsize=(14, 7))

try:
    s = BondPrice_T.loc[(20108, 'Average')]
    s = pd.to_numeric(s, errors='coerce').dropna().sort_index()
except KeyError:
    s = pd.Series(dtype=float)

if len(s) > 0:
    ax.plot(s.index, s.values, marker='.', markersize=5, linewidth=2,
            color='#2c3e50', label='Average Price', zorder=5)
    ax.axhline(100, color='black', alpha=0.3, linestyle='--', linewidth=1.5, label='Par ($100)')

    ax.axvspan(pd.Timestamp('1861-04-12'), pd.Timestamp('1865-05-09'), alpha=0.15, color='#e74c3c', label='Civil War')
    ax.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6', label='Panic of 1873 / Long Depression')
    pmin_d, pmin_v = s.idxmin(), s.min()
    pmax_d, pmax_v = s.idxmax(), s.max()
    ax.annotate(f'LOW: ${pmin_v:.2f}\n({pmin_d.strftime("%b %Y")})',
                xy=(pmin_d, pmin_v), xytext=(30, -35),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#c0392b',
                arrowprops=dict(arrowstyle='->', color='#c0392b', lw=1.2))
    ax.annotate(f'HIGH: ${pmax_v:.2f}\n({pmax_d.strftime("%b %Y")})',
                xy=(pmax_d, pmax_v), xytext=(30, 20),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#27ae60',
                arrowprops=dict(arrowstyle='->', color='#27ae60', lw=1.2))
    ax.set_title('Ten-Forties of 1864 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date'); ax.set_ylabel('Price ($)')
    ax.legend(loc='lower left', fontsize=9, framealpha=0.9)
    ax.grid(True, alpha=0.3)

    print(f"Price Statistics ({len(s)} obs):")
    print(f"  Mean ${s.mean():.2f} | Std ${s.std():.2f} | Range ${s.min():.2f}-${s.max():.2f}")
    print(f"  First obs: {s.index.min().strftime('%Y-%m-%d')} | Last obs: {s.index.max().strftime('%Y-%m-%d')}")
else:
    ax.text(0.5, 0.5, 'No secondary-market price series is recorded\nfor this bond in the Hall-Payne-Sargent database.',
            transform=ax.transAxes, ha='center', va='center', fontsize=14,
            bbox=dict(boxstyle='round,pad=0.5', fc='#fef9e7', ec='#f39c12'))
    ax.set_title('Ten-Forties of 1864 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xticks([]); ax.set_yticks([])

plt.tight_layout()
plt.show()
# Out:
# Price Statistics (174 obs):
#   Mean $107.68 | Std $6.77 | Range $91.00-$119.39
#   First obs: 1864-08-31 | Last obs: 1879-04-30

# %% [markdown]
# ## Price and Quantity Together

# %%
fig, ax1 = plt.subplots(figsize=(14, 6))

ax1.axvspan(pd.Timestamp('1861-04-12'), pd.Timestamp('1865-05-09'), alpha=0.15, color='#e74c3c')
ax1.axvspan(pd.Timestamp('1873-09-18'), pd.Timestamp('1879-03-01'), alpha=0.15, color='#9b59b6')
for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        q = BondQuant_T.loc[(20108, stype)]
        q = q[q.notna()].sort_index()
        if len(q) > 0:
            ax1.fill_between(q.index, q.values / 1e6, alpha=0.2, color='#3498db')
            ax1.plot(q.index, q.values / 1e6, color='#3498db', alpha=0.8,
                     linewidth=1.5, label=f'Quantity ({stype})')
            break
    except KeyError:
        pass

ax1.set_xlabel('Date')
ax1.set_ylabel('Quantity Outstanding ($ millions)', color='#3498db')
ax1.tick_params(axis='y', labelcolor='#3498db')

ax2 = ax1.twinx()
try:
    p = BondPrice_T.loc[(20108, 'Average')]
    p = pd.to_numeric(p, errors='coerce').dropna().sort_index()
    if len(p) > 0:
        ax2.plot(p.index, p.values, color='#e74c3c', marker='.', markersize=3,
                 linewidth=2, label='Average Price')
        ax2.axhline(100, color='gray', alpha=0.3, linestyle='--')
        ax2.set_ylabel('Price ($)', color='#e74c3c')
        ax2.tick_params(axis='y', labelcolor='#e74c3c')
except KeyError:
    pass

ax1.set_title('Ten-Forties of 1864 — Price and Quantity Together', fontsize=14, fontweight='bold')
ax1.grid(True, alpha=0.3)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right', fontsize=9, framealpha=0.9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Volatility & Drawdown

# %%
fig, axes = plt.subplots(2, 1, figsize=(14, 8), gridspec_kw={'height_ratios': [2, 1]})

try:
    p = BondPrice_T.loc[(20108, 'Average')]
    p = pd.to_numeric(p, errors='coerce').dropna().sort_index()
except KeyError:
    p = pd.Series(dtype=float)

ax = axes[0]
if len(p) > 0:
    ax.plot(p.index, p.values, color='#2c3e50', linewidth=2, label='Price')
    ax.axhline(100, color='black', alpha=0.2, linestyle='--')
    running_max = p.expanding().max()
    ax.fill_between(p.index, p.values, running_max.values, alpha=0.3,
                    color='#e74c3c', label='Drawdown from Peak')
    ax.set_title('Price and Drawdown from Peak', fontsize=13, fontweight='bold')
    ax.set_ylabel('Price ($)'); ax.legend(fontsize=9); ax.grid(True, alpha=0.3)
else:
    ax.text(0.5, 0.5, 'No price series available', transform=ax.transAxes, ha='center', fontsize=12)

ax2 = axes[1]
if len(p) >= 12:
    rolling_std = p.rolling(window=12).std().dropna()
    ax2.fill_between(rolling_std.index, rolling_std.values, alpha=0.4, color='#e74c3c')
    ax2.plot(rolling_std.index, rolling_std.values, color='#c0392b', linewidth=1.5)
ax2.set_title('12-Month Rolling Price Volatility (Std Dev)', fontsize=13, fontweight='bold')
ax2.set_xlabel('Date'); ax2.set_ylabel('Std Dev ($)'); ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

if len(p) > 0:
    dd = (p.min() - p.max()) / p.max() * 100
    print(f"\nMaximum drawdown from rolling peak: {dd:.1f}%")
    print(f"  Peak ${p.max():.2f} on {p.idxmax().strftime('%Y-%m-%d')}")
    print(f"  Trough ${p.min():.2f} on {p.idxmin().strftime('%Y-%m-%d')}")
# Out:
# Maximum drawdown from rolling peak: -23.8%
#   Peak $119.39 on 1876-01-31
#   Trough $91.00 on 1865-11-30

# %% [markdown]
# ## Connections
#
# - {ref}`bond-20101-five-twenties-of-1862` — **Five-Twenties of 1862** (Bond ID 20101). Predecessor flagship long-bond; the Ten-Forty was Chase's attempt to lower the coupon below this Five-Twenty's 6%.
# - {ref}`bond-20110-five-twenties-of-june-1864` — **Five-Twenties of June 1864** (Bond ID 20110). Companion 1864 long-bond at the proven 6% rate, placed simultaneously.
# - {ref}`bond-20114-consols-of-1865` — **Consols of 1865** (Bond ID 20114). Postwar refunding instrument that the Ten-Forty's 5% coupon prefigured.

# %% [markdown]
# ## Legacy and Significance
#
# ### Lower-Coupon Precedent
#
# Despite their rocky debut, the Ten-Forties eventually established a crucial precedent: **the U.S. Treasury could issue long-dated debt at coupons below 6%**. This opened the door to the 4.5% and 4% refunding bonds of the 1870s — instruments that would substantially reduce the nation's interest burden as Civil War debt was refinanced.
#
# ### The 40-Year Maturity
#
# A 40-year bond was unusual in 1864 and remained unusual for decades after. Only the refunding bonds of 1870 (notably the 4% Loan of 1907) would carry similar ultra-long maturities. The Ten-Forties thus sit in an interesting position within the term structure of 19th-century U.S. sovereign debt.
#
# ### End of the Chase Era
#
# Symbolically, the Ten-Forties mark the end of Chase's tenure and the transition to a more professionalized Treasury under Fessenden and McCulloch. Chase's legacy as Treasury Secretary is complex: he presided over the greenback, the National Banking Act, the Five-Twenty campaign, and the initial framework for Civil War taxation. He also nearly failed with the Ten-Forties. His departure from Treasury (and elevation to the Chief Justiceship in December 1864) closed a distinct chapter in American fiscal history.

# %% [markdown]
# ## References
#
# - Payne, J., Szoke, A., Hall, G. & Sargent, T. (2025). *Hall-Payne-Sargent US Federal Bond Database.*
# - Bayley, R. A. (1881). *The National Loans of the United States, 1776–1880.*
# - Niven, J. (1995). *Salmon P. Chase: A Biography.* Oxford University Press.
# - Jellison, C. A. (1962). *Fessenden of Maine: Civil War Senator.* Syracuse University Press.
# - Dewey, D. R. (1918). *Financial History of the United States.*
# - Studenski, P. & Krooss, H. E. (1952). *Financial History of the United States.*
# - Friedman, M. & Schwartz, A. J. (1963). *A Monetary History of the United States.*
# - Hammond, B. (1970). *Sovereignty and an Empty Purse.*
#
# ### Primary Source — Bayley (1881)
#
# - **Bayley, R. A.** (1881). *The National Loans of the United States, From July 4, 1776, to June 30, 1880.* Washington: Government Printing Office, ch. 4 ("Ten-Forties of 1864 — Five-Twenties of March, 1864"). Digital MyST edition: see the companion `bayley-myst/` project.
