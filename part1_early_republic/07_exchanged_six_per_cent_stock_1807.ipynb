# %% [markdown]
# (bond-20045-exchanged-six-per-cent-stock-of-1807)=
# # Bond Biography: Exchanged Six Per Cent Stock of 1807
#
# *Bond ID:* **20045** · *Bayley reference:* ch. 2 (*Exchanged and Converted Six Per Cent. Stocks of 1807*) · *Database series:* `BondList[20045]`, `BondPrice_T[(20045, 'Average')]`, `BondQuant_T[(20045, ...)]`
#
# ---
#
# > *"The reduction of the public debt was certainly the principal object in bringing me into office, and I will keep it in my hands… and bring forward the remaining measures myself."*
# > — Albert Gallatin to President Jefferson, 1801.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
import datetime
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'figure.figsize': (14, 6), 'font.size': 12,
    'axes.titlesize': 15, 'axes.labelsize': 12, 'figure.dpi': 110
})

store = pd.HDFStore('../data/BondDF.h5', mode='r')
BondList  = store['BondList']
BondQuant = store['BondQuant']
BondPrice = store['BondPrice']
store.close()

BondQuant_T = BondQuant.transpose()
BondPrice_T = BondPrice.transpose()

bond_id = 20045
print(f"Loaded data for: Exchanged Six Per Cent Stock of 1807 — Bond ID {bond_id}")
print(f"Database contains {len(BondList):,} bond issues spanning {BondList['First Issue Date'].min().year}–{BondList['First Issue Date'].max().year}")
# Out:
# Loaded data for: Exchanged Six Per Cent Stock of 1807 — Bond ID 20045
# Database contains 2,857 bond issues spanning 1777–2015

# %% [markdown]
# ## Overview
#
# Rafael A. Bayley, writing in 1881 in his *National Loans of the United States*, framed this loan in the following terms:
#
# > By the act of February 11, 1807 (2 Statutes, 411), the Secretary of the Treasury was authorized to exchange the unpaid balances of these stocks for a new stock, bearing 6 per cent. interest, and exempt from redemption until eight years should expire.
#
# — Bayley, ch. 2, on the Exchanged and Converted Stocks of 1807.
#
# That contemporary framing is the place to begin. The modern paragraphs that follow extend it with the secondary-market data the Hall–Payne–Sargent Bond Database makes available, and with the broader 21st-century historiographical literature on the loan.
#
# The **Exchanged Six Per Cent Stock of 1807** is one of two paired refunding instruments (alongside the Converted Six Per Cent Stock of 1807, Bond ID 20046) created by the **Act of February 11, 1807**. Together, they were the centerpiece of Treasury Secretary **Albert Gallatin's** systematic effort to **rationalize and consolidate** the diverse mass of older federal debts that had accumulated by the early 1800s.
#
# By 1807, the federal debt portfolio had become bewildering. Holders carried Six Per Cent Stocks (1790, 1796), Three Per Cent Stocks (1790), Deferred Six Per Cent Stocks (1790), Eight Per Cent Loans (1798, 1800), Navy Stocks, Louisiana Six Per Cent Stocks, and various smaller temporary loans. Each had its own maturity, call features, payment schedule, and tax treatment. From the Treasury's standpoint, this complexity was operationally burdensome. From the holder's standpoint, it was confusing and reduced the marketability of older securities.
#
# The Act of February 11, 1807 authorized Gallatin to **exchange older obligations for new, standardized 6% Stocks** with consistent terms. Holders who chose to participate would surrender their old securities and receive in return:
# - The **Exchanged Six Per Cent Stock** (this bond, ID 20045) — for direct one-for-one exchange of older 6% obligations into a newly-numbered, current series.
# - The **Converted Six Per Cent Stock** (Bond ID 20046) — for conversions of fractional or non-6% holdings into 6% Stock equivalents.
#
# In the Hall-Payne-Sargent database, this Exchanged Stock has **no recorded secondary-market price series** — consistent with its character as a refunding instrument that was largely held by long-term investors rather than actively traded. Quantity peaked at **\$5.99 million** in March 1808 and was retired by the early 1820s.

# %% [markdown]
# ## Bayley's Account in Detail (1881)
#
# Bayley's 1881 *National Loans of the United States* devotes substantive attention to this bond. Four passages from his account are reproduced below, with modern commentary woven in. They give the reader the primary-source spine of this biography — the statute text, the placement mechanics, and the post-issuance disposition as recorded by the U.S. Treasury Department officer who compiled the original.
#
# ### The authorizing statute
#
# Bayley begins his account, as he does for every loan in his book, with the statutory text. For this bond he writes:
#
# > On the 29th of December, 1806, John Randolph, from the committee of ways and means of the House of Representatives, presented a bill for the exchange and conversion of the stocks, entitled "An act supplementary to the act entitled an act making provision for the redemption of the whole of the public debt of the United States". … The bill passed the House at the close of the debate by yeas 112, nays 13. It passed the Senate February 7, without amendment and apparently without debate, and was approved February 11, 1807 (2 Statutes, 415).
#
# — *Bayley, ch. 2 (Exchanged and Converted Stocks of 1807), p. 471 — legislative passage of the consolidation act.*
#
# That paragraph is the legal foundation of the bond. Every subsequent operational and financial detail in this biography follows from the statutory powers it conferred on the Treasury.
#
# ### How it was actually placed
#
# Bayley then describes how the Treasury translated statutory authority into actual placement — the subscribers, the marketing, the prices realized, the political context that shaped market reception:
#
# > It provided that a subscription should be opened in the United States and at London and Amsterdam to the full amount of the old 6 per cent., deferred, and 3 per cent. stocks. For any amount subscribed, in the old sixes or deferred stocks, a new 6 per cent. stock was to be issued for the par value of the unredeemed amount of each certificate. The interest on the new stock was to be payable quarterly, and it was to be subject to redemption at the pleasure of the United States.
#
# — *Bayley, ch. 2 — terms of the Exchanged-Stock subscription (London and Amsterdam books opened).*
#
# This operational detail is the kind of material that distinguishes Bayley's primary-source account from purely statistical sources. The price and quantity series in the Hall–Payne–Sargent database tell us *what* happened in the secondary market; Bayley tells us *how* it happened in the primary placement.
#
# ### Outstanding amounts and disposition
#
# Bayley closes most of his loan accounts with concrete tabulated figures — total amount issued, distribution among holders, ultimate retirement schedule:
#
# > It will be observed that the act created two kinds of stocks, one reimbursable at the pleasure of the United States, the other not without the assent of the holder until after an indefinite period. To distinguish these stocks the first was called the "exchanged", the other the "converted" 6 per cents. For these names, however, no authority appears in the act. "Exchanged" 6's were issued amounting to \$6,294,051 12, and of the "converted" \$1,859,850 70. It would appear that the great majority of the holders of the old stocks preferred them to the new.
#
# — *Bayley, ch. 2 — final issuance figures and Bayley's editorial observation that most 1790-vintage holders declined to convert.*
#
# These figures are the data that the modern Hall-Payne-Sargent database extends and corroborates. Where Bayley's tabulated total matches the database's monthly outstanding peak (within rounding), we have strong confidence in the bond's accounting; where they differ, the discrepancy itself carries information about how 19th-century federal debt was tracked.
#
# Read the modern paragraphs that follow with these three Bayley passages in mind. The 21st-century historiography extends Bayley's account; it does not replace it.

# %% [markdown]
# ## Gallatin's Debt-Reduction Program
#
# **Albert Gallatin** (Treasury Secretary 1801–1814) is one of the most underappreciated figures in early American fiscal history. A Geneva-born scholar and long-serving Republican Congressman, Gallatin took office in 1801 with a single overarching goal: **to reduce the federal debt to zero**. He believed (with Jefferson) that excessive sovereign debt corrupted republican government, and he committed himself to systematic debt retirement.
#
# ### The Mechanics of Reduction
#
# Gallatin's program had three pillars:
#
# 1. **Budget Surpluses:** By cutting military and diplomatic spending and benefiting from rising customs revenues, Gallatin generated consistent fiscal surpluses through the 1801–1812 period.
#
# 2. **Sinking Fund Discipline:** He used the Sinking Fund (created by Hamilton in 1790) systematically to retire outstanding debt, applying surpluses to bond purchases or redemptions.
#
# 3. **Debt Consolidation:** This is where the Act of February 11, 1807 came in. By consolidating the older debt into standardized instruments, Gallatin made the remaining outstanding debt easier to track, easier to retire, and cheaper to service.
#
# ### The Refunding Instruments
#
# The Exchanged Six Per Cent Stock and the Converted Six Per Cent Stock together represented a small but symbolically important step in this program. They allowed Gallatin to:
# - Replace older, irregular 6% obligations with a new uniform series.
# - Eliminate the operational complexity of tracking multiple older instruments.
# - Position the remaining debt for systematic retirement through the Sinking Fund.
#
# ### Why "Exchanged" vs. "Converted"
#
# The two stocks served slightly different purposes:
# - **Exchanged Stock:** Direct one-for-one exchange of older 6% obligations whose principal amount could be carried into the new instrument unchanged.
# - **Converted Stock:** For obligations that required arithmetic conversion (e.g., older instruments with different coupon rates that needed to be re-priced into 6% equivalents).
#
# Together, they handled essentially the entire surviving stock of late-1790s and early-1800s federal debt.

# %% [markdown]
# ## Bond Features
#
# | Feature | Detail |
# |---------|--------|
# | **Name** | Exchanged Six Per Cent Stock of 1807 |
# | **Authorizing Act** | February 11, 1807 |
# | **First Issue Date** | September 30, 1807 |
# | **Term** | Indefinite |
# | **Coupon Rate** | 6.0% per annum |
# | **Coupon Frequency** | Quarterly, coin-payable |
# | **Callable** | No (but redeemable at government option) |
# | **Price Sold** | Par |
# | **Peak Outstanding** | \$5.99 million (March 1808) |

# %%
row = BondList.loc[20045]
display_cols = [
    "Treasury's Name Of Issue", 'Authorizing Act', 'Term Of Loan',
    'First Issue Date', 'Redeemable After Date', 'Payable Date',
    'Coupon Rate', 'Coupons Per Year', 'Callable', 'Coin',
    'Price Sold', 'Category L3'
]
print('Bond Features from Database:')
print('=' * 60)
for col in display_cols:
    if col in row.index:
        val = row[col]
        if pd.notna(val) and str(val).strip() != 'nan':
            print(f'  {col:<28} {val}')
# Out:
# Bond Features from Database:
# ...
#   Treasury's Name Of Issue     Exchanged Six Per Cent. Stock of 1807
#   Authorizing Act              February 11, 1807
#   Term Of Loan                 indefinite
#   First Issue Date             1807-09-30 00:00:00
#   Coupon Rate                  6.0
#   Coupons Per Year             4.0
#   Callable                     0.0
#   Coin                         1.0
#   Price Sold                   1.0
#   Category L3                  Long Term Bond

# %% [markdown]
# ## Historical Context
#
# | Date | Event | Category |
# |------|-------|----------|
# | 1801-03-04 | Jefferson inaugurated; Gallatin nominated | Politics |
# | 1801-05-14 | Gallatin takes office | Politics |
# | 1803-04-30 | Louisiana Purchase | Other |
# | 1807-02-11 | Authorizing Act | Legislation |
# | 1807-06-22 | *Chesapeake-Leopard* affair (impressment crisis) | Crisis |
# | 1807-09-30 | First issue | Bond |
# | 1807-12-22 | Embargo Act | Legislation |
# | 1812-06-18 | War of 1812 | War |
# | 1814-08-24 | Burning of Washington | Military |
# | 1819-01-01 | Panic of 1819 | Crisis |
# | 1824-03-31 | Final database observation | Bond |

# %%
fig, ax = plt.subplots(figsize=(16, 4.5))
from datetime import datetime as dt

lifecycle = [
    ('Gallatin Takes Office', '1801-05-14', '#1f77b4'),
    ('Louisiana Purchase', '1803-04-30', '#1f77b4'),
    ('Authorizing Act', '1807-02-11', '#2ecc71'),
    ('Chesapeake-Leopard', '1807-06-22', '#c0392b'),
    ('First Issue', '1807-09-30', '#1f77b4'),
    ('Embargo Act', '1807-12-22', '#f39c12'),
    ('War of 1812', '1812-06-18', '#e74c3c'),
    ('Panic of 1819', '1819-01-01', '#9b59b6'),
]

ax.axvspan(mdates.date2num(dt.strptime('1812-06-18', '%Y-%m-%d')), mdates.date2num(dt.strptime('1815-02-18', '%Y-%m-%d')), alpha=0.15, color='#e74c3c', label='War of 1812')
ax.axvspan(mdates.date2num(dt.strptime('1819-01-01', '%Y-%m-%d')), mdates.date2num(dt.strptime('1821-12-31', '%Y-%m-%d')), alpha=0.15, color='#9b59b6', label='Panic of 1819')

for i, (label, date_str, color) in enumerate(lifecycle):
    d = dt.strptime(date_str, '%Y-%m-%d')
    y_pos = 0.3 if i % 2 == 0 else -0.3
    ax.plot(mdates.date2num(d), 0, 'D', color=color, markersize=9, zorder=5)
    ax.annotate(f'{label}\n{date_str}', (mdates.date2num(d), y_pos),
                ha='center', va='bottom' if y_pos > 0 else 'top',
                fontsize=7.5, fontweight='bold', color=color,
                arrowprops=dict(arrowstyle='->', color=color, lw=0.8))

ax.set_yticks([])
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.set_title('Exchanged Six Per Cent Stock of 1807 — Lifecycle Timeline', fontsize=14, fontweight='bold')
ax.set_ylim(-1.2, 1.2)
ax.legend(loc='upper right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quantity Outstanding
#
# The Exchanged Six Per Cent Stock peaked rapidly at \$5.99 million in March 1808 — almost immediately after issuance authority was activated. This pattern is typical of refunding instruments: holders elect to participate quickly (within months), and outstanding balance reaches its peak almost immediately. After 1810, balance declined steadily as Gallatin (and his successors) used Sinking Fund operations to retire the Stock. By 1820, outstanding had fallen to under \$2 million; by 1824, the Stock was effectively extinguished.

# %%
fig, ax = plt.subplots(figsize=(14, 6))

ax.axvspan(pd.Timestamp('1812-06-18'), pd.Timestamp('1815-02-18'), alpha=0.15, color='#e74c3c', label='War of 1812')
ax.axvspan(pd.Timestamp('1819-01-01'), pd.Timestamp('1821-12-31'), alpha=0.15, color='#9b59b6', label='Panic of 1819')
for stype, color, ls in [('Public Holdings', '#1f77b4', '-'),
                          ('Total Outstanding', '#ff7f0e', '--')]:
    try:
        s = BondQuant_T.loc[(20045, stype)]
        s = s[s.notna()].sort_index()
        if len(s) > 0:
            ax.plot(s.index, s.values / 1e6, linewidth=2, linestyle=ls, color=color,
                    label=stype, marker='.', markersize=3)
    except KeyError:
        pass

ax.set_title('Exchanged Six Per Cent Stock of 1807 — Outstanding Quantity', fontsize=14, fontweight='bold')
ax.set_xlabel('Date'); ax.set_ylabel('Amount ($ millions)')
ax.legend(fontsize=10); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        s = BondQuant_T.loc[(20045, stype)]
        s = pd.to_numeric(s, errors='coerce').dropna()
        if len(s) > 0:
            print(f"{stype}: max ${s.max()/1e6:.2f}M on {s.idxmax().strftime('%Y-%m-%d')}, {len(s)} obs, final ${s.iloc[-1]/1e6:.3f}M on {s.index[-1].strftime('%Y-%m-%d')}")
    except KeyError:
        pass
# Out:
# Total Outstanding: max $5.99M on 1808-03-31, 67 obs, final $0.004M on 1824-03-31
# Public Holdings: max $5.99M on 1808-03-31, 67 obs, final $0.004M on 1824-03-31

# %% [markdown]
# ## Price Data
#
# The Hall-Payne-Sargent database does not record a secondary-market price series for this specific Stock. Refunding instruments of this kind were typically held by long-term investors who had elected to participate in the exchange, and they generally traded only in line with the underlying 6% Stock benchmark. For traded-price views of comparable 6% federal securities of the period, see the chapter on the Six Per Cent Stock of 1790 (Bond ID 20021) and the Louisiana Six Per Cent Stock (Bond ID 20044).

# %%
fig, ax = plt.subplots(figsize=(14, 7))

try:
    s = BondPrice_T.loc[(20045, 'Average')]
    s = pd.to_numeric(s, errors='coerce').dropna().sort_index()
except KeyError:
    s = pd.Series(dtype=float)

if len(s) > 0:
    ax.plot(s.index, s.values, marker='.', markersize=5, linewidth=2,
            color='#2c3e50', label='Average Price', zorder=5)
    ax.axhline(100, color='black', alpha=0.3, linestyle='--', linewidth=1.5, label='Par ($100)')

    ax.axvspan(pd.Timestamp('1812-06-18'), pd.Timestamp('1815-02-18'), alpha=0.15, color='#e74c3c', label='War of 1812')
    ax.axvspan(pd.Timestamp('1819-01-01'), pd.Timestamp('1821-12-31'), alpha=0.15, color='#9b59b6', label='Panic of 1819')
    pmin_d, pmin_v = s.idxmin(), s.min()
    pmax_d, pmax_v = s.idxmax(), s.max()
    ax.annotate(f'LOW: ${pmin_v:.2f}\n({pmin_d.strftime("%b %Y")})',
                xy=(pmin_d, pmin_v), xytext=(30, -35),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#c0392b',
                arrowprops=dict(arrowstyle='->', color='#c0392b', lw=1.2))
    ax.annotate(f'HIGH: ${pmax_v:.2f}\n({pmax_d.strftime("%b %Y")})',
                xy=(pmax_d, pmax_v), xytext=(30, 20),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#27ae60',
                arrowprops=dict(arrowstyle='->', color='#27ae60', lw=1.2))
    ax.set_title('Exchanged Six Per Cent Stock of 1807 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date'); ax.set_ylabel('Price ($)')
    ax.legend(loc='lower left', fontsize=9, framealpha=0.9)
    ax.grid(True, alpha=0.3)

    print(f"Price Statistics ({len(s)} obs):")
    print(f"  Mean ${s.mean():.2f} | Std ${s.std():.2f} | Range ${s.min():.2f}-${s.max():.2f}")
    print(f"  First obs: {s.index.min().strftime('%Y-%m-%d')} | Last obs: {s.index.max().strftime('%Y-%m-%d')}")
else:
    ax.text(0.5, 0.5, 'No secondary-market price series is recorded\nfor this bond in the Hall-Payne-Sargent database.',
            transform=ax.transAxes, ha='center', va='center', fontsize=14,
            bbox=dict(boxstyle='round,pad=0.5', fc='#fef9e7', ec='#f39c12'))
    ax.set_title('Exchanged Six Per Cent Stock of 1807 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xticks([]); ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Connections
#
# - {ref}`bond-20021-six-per-cent-stock-of-1790` — **Six Per Cent Stock of 1790** (Bond ID 20021). Underlying obligation that this Exchanged Stock partly absorbed via consolidation.
# - {ref}`bond-20046-converted-six-per-cent-stock-of-1807` — **Converted Six Per Cent Stock of 1807** (Bond ID 20046). Sister consolidation instrument under the same Act of February 11, 1807.
# - {ref}`bond-20048-six-per-cent-loan-of-1812` — **Six Per Cent Loan of 1812** (Bond ID 20048). Next major long bond after this consolidation closed the 1790-vintage debt cycle.

# %% [markdown]
# ## Legacy and Significance
#
# ### Standardization Triumph
#
# The Exchanged Stock represents a quiet triumph of **financial standardization**. By collapsing multiple older 6% obligations into a single uniform series, Gallatin reduced the operational complexity of the federal debt and made the Treasury's job easier. This is the same impulse that would later drive the **Consols of 1865** under McCulloch and the **Funding Act of 1870** under Sherman — and it ultimately leads to modern Treasury practice, where outstanding federal debt is divided into a small number of standardized instrument classes (bills, notes, bonds, TIPS).
#
# ### Part of the Jeffersonian Debt Reduction
#
# Together with its sister Converted Stock and the broader Sinking Fund operations, the Exchanged Stock helped Gallatin make extraordinary progress in reducing the federal debt. Federal debt outstanding fell from **\$83 million in 1801** (when Gallatin took office) to **\$45 million in 1812** (the eve of war) — a reduction of nearly half over a single decade. This reduction would have been even more dramatic but for the Louisiana Purchase, which added \$11.25 million to the debt.
#
# ### The War Interrupts
#
# The War of 1812 ultimately reversed Gallatin's debt-reduction program. By 1816, federal debt had grown back to **\$127 million** — its highest level in absolute terms since 1790. But the institutional architecture Gallatin had built — including the standardized refunding mechanisms exemplified by the Exchanged Stock — would prove instrumental in managing the much larger debt burden of the postwar era.

# %% [markdown]
# ## References
#
# - Payne, J., Szoke, A., Hall, G. & Sargent, T. (2025). *Hall-Payne-Sargent US Federal Bond Database.*
# - Bayley, R. A. (1881). *The National Loans of the United States, 1776–1880.*
# - Walters, R. (1957). *Albert Gallatin: Jeffersonian Financier and Diplomat.*
# - Sylla, R. (2011). *Founding Choices.*
# - Edling, M. M. (2014). *A Hercules in the Cradle.*
# - Adams, H. (1879). *The Life of Albert Gallatin.* J. B. Lippincott.
# - Burrows, E. G. (1986). *Albert Gallatin and the Political Economy of Republicanism, 1761–1800.* Garland.
#
# ### Primary Source — Bayley (1881)
#
# - **Bayley, R. A.** (1881). *The National Loans of the United States, From July 4, 1776, to June 30, 1880.* Washington: Government Printing Office, ch. 2 ("Exchanged and Converted Six Per Cent. Stocks of 1807"). Digital MyST edition: see the companion `bayley-myst/` project.
