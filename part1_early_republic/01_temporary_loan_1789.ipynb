# %% [markdown]
# (bond-20019-temporary-loan-of-1789)=
# # Bond Biography: Temporary Loan of 1789
#
# *Bond ID:* **20019** · *Bayley reference:* ch. 2 (*Temporary Loan of 1789*) · *Database series:* `BondList[20019]`, `BondPrice_T[(20019, 'Average')]`, `BondQuant_T[(20019, ...)]`
#
# ---
#
# > *"The general inducements to a provision for the public debt were: To preserve the public faith and integrity by fulfilling, as far as was practicable, the public engagements."*
# > — Alexander Hamilton, in correspondence with President Washington, July 29, 1792 — quoted by Bayley, ch. 2.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.dates as mdates
import datetime
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({
    'figure.figsize': (14, 6), 'font.size': 12,
    'axes.titlesize': 15, 'axes.labelsize': 12, 'figure.dpi': 110
})

store = pd.HDFStore('../data/BondDF.h5', mode='r')
BondList  = store['BondList']
BondQuant = store['BondQuant']
BondPrice = store['BondPrice']
store.close()

BondQuant_T = BondQuant.transpose()
BondPrice_T = BondPrice.transpose()

bond_id = 20019
print(f"Loaded data for: Temporary Loan of 1789 — Bond ID {bond_id}")
print(f"Database contains {len(BondList):,} bond issues spanning {BondList['First Issue Date'].min().year}–{BondList['First Issue Date'].max().year}")
# Out:
# Loaded data for: Temporary Loan of 1789 — Bond ID 20019
# Database contains 2,857 bond issues spanning 1777–2015

# %% [markdown]
# ## Overview
#
# Rafael A. Bayley, writing in 1881 in his *National Loans of the United States*, framed this loan in the following terms:
#
# > The mass of debt which devolved upon the United States, as an inheritance from the Continental Congress and the several colonies, engaged the attention of the national legislature soon after the adoption of the Constitution.
#
# — Bayley, *National Loans*, ch. 2, p. 83.
#
# That contemporary framing is the place to begin. The modern paragraphs that follow extend it with the secondary-market data the Hall–Payne–Sargent Bond Database makes available, and with the broader 21st-century historiographical literature on the loan.
#
# The **Temporary Loan of 1789** is, by every meaningful measure, the **first federal loan of the United States of America under the Constitution**. Negotiated by **Alexander Hamilton** in his earliest weeks as the first Secretary of the Treasury, it was tiny by later standards — peak outstanding of just **\$100,000** — but its symbolic and operational importance was enormous.
#
# The Constitution had been ratified in 1788. George Washington took office on April 30, 1789. Hamilton was confirmed as Secretary of the Treasury on **September 11, 1789**. Within weeks, before he had even submitted his famous *Report on Public Credit*, Hamilton needed cash. The new federal government had inherited a chaotic mass of Revolutionary War debts (the "domestic debt"), foreign loans from the Dutch and the French, and obligations to soldiers and suppliers — but no working capital for day-to-day operations. Customs revenues from the new tariff act of July 1789 were starting to flow, but they would take months to accumulate.
#
# The **Temporary Loan of 1789** was Hamilton's bridge financing: a small short-term advance, secured by his own signature as Secretary, on which the federal government could meet its first payroll, pay its earliest contractors, and demonstrate to creditors at home and abroad that the new constitutional government could conduct its financial affairs in an orderly manner. The loan came primarily from the **Bank of North America** (Philadelphia) and the **Bank of New York** — the only two commercial banks of consequence in the United States at the time.
#
# It was retired within months. The Hall-Payne-Sargent database records only **3 quantity observations** (September 1789, December 1789, March 1790), peaking at \$100,000 and falling to \$90,000 by the final observation. No secondary-market price series exists — this was not a marketable instrument in any modern sense, but rather a private credit arrangement between the Treasury and a small handful of banks.

# %% [markdown]
# ## Bayley's Account in Detail (1881)
#
# Bayley's 1881 *National Loans of the United States* devotes substantive attention to this bond. Four passages from his account are reproduced below, with modern commentary woven in. They give the reader the primary-source spine of this biography — the statute text, the placement mechanics, and the post-issuance disposition as recorded by the U.S. Treasury Department officer who compiled the original.
#
# ### The authorizing statute
#
# Bayley begins his account, as he does for every loan in his book, with the statutory text. For this bond he writes:
#
# > On assuming the position of Secretary of the Treasury, Hamilton found himself entirely without funds to meet the ordinary expenses of the government, except by borrowing, until such time as the revenues from duties on imports and tonnage began to come into the treasury. Under these circumstances he was forced to make arrangements with the Bank of New York and the Bank of North America for temporary loans, and it was the money received from these banks that paid the first installment of salary due President Washington, senators, representatives, and officers of Congress, during the first session under the Constitution, which began at the city of New York, March 4, 1789.
#
# — *Bayley, ch. 2 (Temporary Loan of 1789), p. 8.*
#
# That paragraph is the legal foundation of the bond. Every subsequent operational and financial detail in this biography follows from the statutory powers it conferred on the Treasury.
#
# ### How it was actually placed
#
# Bayley then describes how the Treasury translated statutory authority into actual placement — the subscribers, the marketing, the prices realized, the political context that shaped market reception:
#
# > September 13, 1789, \$29,069 — A loan agreed to be made by the Bank of New York to the Secretary of War, in pursuance of an appropriation made by an act of Congress of the 20th of August, 1789 (1 Statutes, 54). … September 14, 1789, \$30,000 — A loan agreed to be made by the Bank of New York to the United States. … September 21, 1789, \$50,000 — A loan agreed to be made by the Bank of North America to the United States. … October 1, 1789, \$20,000 … October 10, 1789, \$20,000 … December 1, 1789, \$10,000 … December 2, 1789, \$20,000 … February 17, 1790, \$20,000. These loans were all repaid according to contract, the final payment being made June 8, 1790.
#
# — *Bayley, ch. 2, summarizing Hamilton's reports — list of nine specific bank-by-bank installments and the final June 1790 retirement.*
#
# This operational detail is the kind of material that distinguishes Bayley's primary-source account from purely statistical sources. The price and quantity series in the Hall–Payne–Sargent database tell us *what* happened in the secondary market; Bayley tells us *how* it happened in the primary placement.
#
# ### Outstanding amounts and disposition
#
# Bayley closes most of his loan accounts with concrete tabulated figures — total amount issued, distribution among holders, ultimate retirement schedule:
#
# > As a further anticipation of the receipts into the treasury, to satisfy immediate demands upon it, will be unavoidable, it is necessary that this also should be provided for. Obvious considerations dictate the propriety, in future cases, of making previous provision, by law, for such loans as the public exigencies may call for, defining their extent, and giving special authority to make them.
#
# — *Hamilton, *Report to the House of Representatives*, March 1, 1790 — quoted in Bayley, ch. 2.*
#
# These figures are the data that the modern Hall-Payne-Sargent database extends and corroborates. Where Bayley's tabulated total matches the database's monthly outstanding peak (within rounding), we have strong confidence in the bond's accounting; where they differ, the discrepancy itself carries information about how 19th-century federal debt was tracked.
#
# Read the modern paragraphs that follow with these three Bayley passages in mind. The 21st-century historiography extends Bayley's account; it does not replace it.

# %% [markdown]
# ## Hamilton's Working-Capital Problem
#
# The summer of 1789 found the federal government in a peculiar position: rich in moral authority, but acutely short of cash. The three predecessor regimes — the Continental Congress (1775–1781), the Confederation Congress (1781–1788), and the new federal government (March–September 1789) — had together accumulated enormous debts, but the new Treasury had inherited essentially no liquid assets.
#
# ### What Hamilton Inherited
#
# | Component | Estimated Amount | Status |
# |-----------|------------------|--------|
# | Foreign debt (mostly Dutch and French loans) | \$11.7 million | In default on most coupons |
# | Domestic debt (continental + state war debts) | ~\$60 million | Trading at deep discounts (15-25¢ on the dollar) |
# | Soldier and supplier arrears | uncertain | Largely unpaid |
# | Operating cash | ~\$0 | Essentially nil |
#
# ### The Tariff of July 4, 1789
#
# The First Congress had passed the Tariff Act of July 4, 1789 — by intentional symbolism enacted on Independence Day — to provide the new government with revenue. But customs duties needed time to be collected, and the receiving infrastructure (customs collectors, ports of entry, weights and measures officials) had to be built from scratch. **In the meantime, the government needed to function**.
#
# ### The Loan
#
# Hamilton turned to two banks: the **Bank of North America** (chartered 1781 by Congress, by 1789 a Pennsylvania-chartered private bank) and the **Bank of New York** (founded 1784, partly by Hamilton himself). Both extended short-term credit at 6% interest — a competitive rate for the period — with no formal collateral beyond the Secretary's pledge of forthcoming customs revenues.
#
# This was, in effect, the **first United States Treasury borrowing operation under the Constitution**. The Act of August 4, 1790 (the Funding Act, see Bond IDs 20021–20023) would soon supersede it with a much larger and more ambitious refunding program. But the Temporary Loan of 1789 had already done its essential work: it had proven that the new government could borrow.

# %% [markdown]
# ## Bond Features
#
# | Feature | Detail |
# |---------|--------|
# | **Name** | Temporary Loan of 1789 |
# | **Authorizing Authority** | Secretary of the Treasury (no specific statute) |
# | **First Issue Date** | September 30, 1789 |
# | **Term** | Temporary (months, not years) |
# | **Coupon Rate** | 6.0% per annum |
# | **Coupon Frequency** | Effectively at maturity |
# | **Coin Payable** | Yes |
# | **Lenders** | Bank of North America, Bank of New York |
# | **Peak Outstanding** | \$100,000 (September 1789) |
# | **Price Sold** | Par |
# | **Final Retirement** | Early 1790, replaced by the Temporary Loan of 1790 |

# %%
row = BondList.loc[20019]
display_cols = [
    "Treasury's Name Of Issue", 'Authorizing Act', 'Term Of Loan',
    'First Issue Date', 'Redeemable After Date', 'Payable Date',
    'Coupon Rate', 'Coupons Per Year', 'Callable', 'Coin',
    'Price Sold', 'Category L3'
]
print('Bond Features from Database:')
print('=' * 60)
for col in display_cols:
    if col in row.index:
        val = row[col]
        if pd.notna(val) and str(val).strip() != 'nan':
            print(f'  {col:<28} {val}')
# Out:
# Bond Features from Database:
# ...
#   Treasury's Name Of Issue     Temporary Loan of 1789
#   Authorizing Act              Secretary of the Treasury
#   Term Of Loan                 temporary
#   First Issue Date             1789-09-30 00:00:00
#   Coupon Rate                  6.0
#   Coupons Per Year             0.0
#   Callable                     0.0
#   Coin                         1.0
#   Price Sold                   1.0
#   Category L3                  Temporary Loan

# %% [markdown]
# ## Historical Context
#
# | Date | Event | Category |
# |------|-------|----------|
# | 1788-06-21 | Constitution ratified by ninth state (NH) | Politics |
# | 1789-04-30 | Washington inaugurated | Politics |
# | 1789-07-04 | Tariff Act of 1789 (first revenue measure) | Legislation |
# | 1789-09-02 | Treasury Department established | Legislation |
# | 1789-09-11 | Hamilton confirmed as Treasury Secretary | Politics |
# | 1789-09-30 | First issue of Temporary Loan | Bond |
# | 1790-01-09 | Hamilton's *Report on Public Credit* | Policy |
# | 1790-03-26 | Authorizing Act for Temporary Loan of 1790 | Legislation |
# | 1790-08-04 | Funding Act — 1790 Stocks authorized | Legislation |
#
# This bond's life is the brief window between Hamilton's swearing-in and his comprehensive funding plan. It is, in effect, the **prelude** to the entire American debt-management architecture.

# %%
fig, ax = plt.subplots(figsize=(16, 4.5))
from datetime import datetime as dt

lifecycle = [
    ('Constitution Ratified', '1788-06-21', '#2ecc71'),
    ('Washington Inaugurated', '1789-04-30', '#1f77b4'),
    ('Hamilton Confirmed', '1789-09-11', '#1f77b4'),
    ('First Issue', '1789-09-30', '#e67e22'),
    ('Hamilton Report', '1790-01-09', '#2ecc71'),
    ('Temp Loan of 1790', '1790-03-26', '#1f77b4'),
    ('Funding Act', '1790-08-04', '#2ecc71'),
]


for i, (label, date_str, color) in enumerate(lifecycle):
    d = dt.strptime(date_str, '%Y-%m-%d')
    y_pos = 0.3 if i % 2 == 0 else -0.3
    ax.plot(mdates.date2num(d), 0, 'D', color=color, markersize=9, zorder=5)
    ax.annotate(f'{label}\n{date_str}', (mdates.date2num(d), y_pos),
                ha='center', va='bottom' if y_pos > 0 else 'top',
                fontsize=7.5, fontweight='bold', color=color,
                arrowprops=dict(arrowstyle='->', color=color, lw=0.8))

ax.set_yticks([])
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_major_locator(mdates.YearLocator(2))
ax.set_title('Temporary Loan of 1789 — Lifecycle Timeline', fontsize=14, fontweight='bold')
ax.set_ylim(-1.2, 1.2)
ax.legend(loc='upper right', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quantity Outstanding
#
# The database records only three observations of this bond, all in the autumn of 1789 and winter of 1789-1790. Peak outstanding was \$100,000, retiring to \$90,000 within six months. This brief, vanishingly small footprint is faithful to the bond's nature: it was a one-time bridge facility, not a sustained financing instrument.

# %%
fig, ax = plt.subplots(figsize=(14, 6))


for stype, color, ls in [('Public Holdings', '#1f77b4', '-'),
                          ('Total Outstanding', '#ff7f0e', '--')]:
    try:
        s = BondQuant_T.loc[(20019, stype)]
        s = s[s.notna()].sort_index()
        if len(s) > 0:
            ax.plot(s.index, s.values / 1e6, linewidth=2, linestyle=ls, color=color,
                    label=stype, marker='.', markersize=3)
    except KeyError:
        pass

ax.set_title('Temporary Loan of 1789 — Outstanding Quantity', fontsize=14, fontweight='bold')
ax.set_xlabel('Date'); ax.set_ylabel('Amount ($ millions)')
ax.legend(fontsize=10); ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

for stype in ['Total Outstanding', 'Public Holdings']:
    try:
        s = BondQuant_T.loc[(20019, stype)]
        s = pd.to_numeric(s, errors='coerce').dropna()
        if len(s) > 0:
            print(f"{stype}: max ${s.max()/1e6:.2f}M on {s.idxmax().strftime('%Y-%m-%d')}, {len(s)} obs, final ${s.iloc[-1]/1e6:.3f}M on {s.index[-1].strftime('%Y-%m-%d')}")
    except KeyError:
        pass
# Out:
# Total Outstanding: max $0.10M on 1789-09-30, 3 obs, final $0.091M on 1790-03-31
# Public Holdings: max $0.10M on 1789-09-30, 3 obs, final $0.091M on 1790-03-31

# %% [markdown]
# ## Price Data
#
# No secondary-market price series exists for this bond. It was held by two banks under direct contractual arrangement with the Treasury and never traded.

# %%
fig, ax = plt.subplots(figsize=(14, 7))

try:
    s = BondPrice_T.loc[(20019, 'Average')]
    s = pd.to_numeric(s, errors='coerce').dropna().sort_index()
except KeyError:
    s = pd.Series(dtype=float)

if len(s) > 0:
    ax.plot(s.index, s.values, marker='.', markersize=5, linewidth=2,
            color='#2c3e50', label='Average Price', zorder=5)
    ax.axhline(100, color='black', alpha=0.3, linestyle='--', linewidth=1.5, label='Par ($100)')


    pmin_d, pmin_v = s.idxmin(), s.min()
    pmax_d, pmax_v = s.idxmax(), s.max()
    ax.annotate(f'LOW: ${pmin_v:.2f}\n({pmin_d.strftime("%b %Y")})',
                xy=(pmin_d, pmin_v), xytext=(30, -35),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#c0392b',
                arrowprops=dict(arrowstyle='->', color='#c0392b', lw=1.2))
    ax.annotate(f'HIGH: ${pmax_v:.2f}\n({pmax_d.strftime("%b %Y")})',
                xy=(pmax_d, pmax_v), xytext=(30, 20),
                textcoords='offset points', fontsize=10, fontweight='bold', color='#27ae60',
                arrowprops=dict(arrowstyle='->', color='#27ae60', lw=1.2))
    ax.set_title('Temporary Loan of 1789 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xlabel('Date'); ax.set_ylabel('Price ($)')
    ax.legend(loc='lower left', fontsize=9, framealpha=0.9)
    ax.grid(True, alpha=0.3)

    print(f"Price Statistics ({len(s)} obs):")
    print(f"  Mean ${s.mean():.2f} | Std ${s.std():.2f} | Range ${s.min():.2f}-${s.max():.2f}")
    print(f"  First obs: {s.index.min().strftime('%Y-%m-%d')} | Last obs: {s.index.max().strftime('%Y-%m-%d')}")
else:
    ax.text(0.5, 0.5, 'No secondary-market price series is recorded\nfor this bond in the Hall-Payne-Sargent database.',
            transform=ax.transAxes, ha='center', va='center', fontsize=14,
            bbox=dict(boxstyle='round,pad=0.5', fc='#fef9e7', ec='#f39c12'))
    ax.set_title('Temporary Loan of 1789 — Secondary Market Price', fontsize=14, fontweight='bold')
    ax.set_xticks([]); ax.set_yticks([])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Connections
#
# - {ref}`bond-20020-temporary-loan-of-1790` — **Temporary Loan of 1790** (Bond ID 20020). Direct successor; the same emergency-financing role formalized under congressional statute.
# - {ref}`bond-20021-six-per-cent-stock-of-1790` — **Six Per Cent Stock of 1790** (Bond ID 20021). The major refunding instrument that absorbed the political and statutory work this temporary loan made possible.
# - {ref}`bond-20023-three-per-cent-stock-of-1790` — **Three Per Cent Stock of 1790** (Bond ID 20023). Capitalized the back interest on Revolutionary obligations the Temporary Loans had bridged.

# %% [markdown]
# ## Legacy and Significance
#
# ### The First Federal Bond
#
# The Temporary Loan of 1789 is, in any meaningful sense, **the first federal bond of the United States under the Constitution**. The earlier Holland Loans (e.g., Bond ID 20009) were initiated under the Articles of Confederation, even if some were managed by the new federal Treasury. Everything else that follows in the Hall-Payne-Sargent database — every Liberty Bond, every Treasury bill, every Five-Twenty — descends from this small autumn-1789 transaction.
#
# ### A Demonstration of Constitutional Authority
#
# By executing a borrowing operation in his earliest weeks, Hamilton demonstrated that **the constitutional government had the operational capacity to conduct sovereign finance**. This mattered enormously: the Anti-Federalist critique of the Constitution had warned that a strong central government would be paralyzed by partisanship and incompetence. Hamilton's quick, efficient borrowing rebutted that prediction.
#
# ### Establishing a Banking Relationship
#
# The Bank of North America and the Bank of New York extended this credit not from charity but because they believed they would be repaid. By repaying both quickly and at full value, Hamilton **established the model relationship between the federal government and private banks** — a relationship that would expand dramatically with the chartering of the First Bank of the United States in February 1791.
#
# ### A Hint of What Was to Come
#
# The Temporary Loan of 1789 is, in essence, a footnote — but it is the footnote that opens the entire history of American sovereign debt. Within twelve months, the same Hamilton would propose, design, and steer through Congress the largest debt-restructuring operation in early-modern history: the funding of \$77 million of Revolutionary debt at 6%, deferred-6%, and 3% coupons, an operation that would make the United States a credit-worthy nation overnight (see Bond IDs 20021, 20022, 20023).

# %% [markdown]
# ## References
#
# ### Primary Database
# - Payne, J., Szoke, A., Hall, G. & Sargent, T. (2025). *Hall-Payne-Sargent US Federal Bond Database.*
#
# ### Primary Sources
# - Hamilton, A. (1790). *Report on Public Credit.* January 9, 1790.
# - *Annals of Congress,* First Congress, Sessions 1–2.
#
# ### Scholarly Works
# - Bayley, R. A. (1881). *The National Loans of the United States, 1776–1880.*
# - Sylla, R. (2011). "Financial Foundations: Public Credit, the National Bank, and Securities Markets." In Irwin & Sylla, eds., *Founding Choices.* University of Chicago Press.
# - Chernow, R. (2004). *Alexander Hamilton.* Penguin Press.
# - McDonald, F. (1979). *Alexander Hamilton: A Biography.* W. W. Norton.
# - Wright, R. E. (2002). *Hamilton Unbound: Finance and the Creation of the American Republic.* Greenwood.
# - Edling, M. M. (2014). *A Hercules in the Cradle: War, Money, and the American State, 1783–1867.* University of Chicago Press.
#
# ### Primary Source — Bayley (1881)
#
# - **Bayley, R. A.** (1881). *The National Loans of the United States, From July 4, 1776, to June 30, 1880.* Washington: Government Printing Office, ch. 2 ("Temporary Loan of 1789"). Digital MyST edition: see the companion `bayley-myst/` project.
